# %%
import pandas as pd
import importlib.util
import sklearn
import numpy as np
from pathlib import Path
import joblib
import os

# %%
output_dir = "classification_results_2023/"
all_patient_data = pd.read_csv("Combined_AM_Data.csv")

# %%
all_patient_data.columns
# Out:
# Index(['id', 'date', 'age', 'sex', 'BMI', 'income', 'road_dist', 'cooking',
#        'am_pef_org', 'y_am_pef', 'tempin', 'humidin', 'pm25in', 'co2in',
#        'tempdiffin', 'humidiffin', 'pm25diffin', 'pm10', 'pm25', 'o3', 'no2',
#        'co', 'so2', 'temp', 'windsd', 'humid', 'varp', 'dewpt', 'airp', 'seap',
#        'solrhr', 'solramnt', 'grdt', 'class'],
#       dtype='object')

# %%
# Loading classification.py
spec = importlib.util.spec_from_file_location('classification', r"Classificationv3.py")
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

# %%
predictColumn = "class"
minorityVariable = 0 
classes = all_patient_data[predictColumn].unique().tolist()

n_classes = len(classes)

if n_classes > 2 :
    logit_reg_model = sklearn.linear_model.LogisticRegression(solver='saga', multi_class='multinomial')
else :
    logit_reg_model = sklearn.linear_model.LogisticRegression(solver='liblinear', multi_class='auto')

cls = [ "DecisionTree" , sklearn.tree.DecisionTreeClassifier(max_depth=4),
        "K-NN"              , sklearn.neighbors.KNeighborsClassifier(),
        "Logit Regression"  , logit_reg_model,
        "Naive Bayes"       , sklearn.gaussian_process.GaussianProcessClassifier()
];

# %%
EVALUATION_METRICS = ['Weighted Accuracy', 'Sensitivity/Recall', 'Precision_avg', 'F1_avg', 'Specificity', 'Precision', 'Precision_class1', 'F1', 'F1_class1']
REQUIRED_COLUMNS = ['income','road_dist','cooking','y_am_pef','tempin','humidin','pm25in','co2in','tempdiffin','humidiffin','pm25diffin','pm10','pm25','o3','no2','co','so2','temp','windsd','humid','varp','dewpt','airp','seap','solrhr','solramnt','grdt','class']

# %%
# %run "Classificationv3.py"
# %run "Balance.py"

# %%
def classification_func(file_name, predictCol, minorVar, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df):

    print('~~~~~~~~~~~~~~~~~', file_name,'~~~~~~~~~~~~~~~~~~~~~~')

    dataset_dir = Path(output_dir + patient_id+category_group +  "/diagrams/" + file_name + '/') 

    # Create Directory for this patient
    if not (dataset_dir.exists() and dataset_dir.is_dir()):
        os.makedirs(dataset_dir)

    save_path = output_dir+ patient_id+category_group +'/diagrams/' + file_name + '/sklearn_models_balanced_for_train_'

    CLASS_VAR = predictCol
    MINORITY_VAR = minorVar
    bestDT = module.Classify(patient_id_df, True, class_var=CLASS_VAR, minority_var=MINORITY_VAR, drawConfusionMatrix=True, classifiers=cls, scale=True, save_path=save_path, after_split=True)

    confusion_matrixes_file = save_path + "confusion_mat_" + category_group + "_"+ file_name
    module.save_confusion_matrix(bestDT[1], confusion_matrixes_file)
    roc_curve_file = save_path + "roc_curve_" + category_group + "_"+ file_name
    module.save_Draw_Roc(bestDT[2], roc_curve_file)
    if len(bestDT[3])!=0:
      featureImportance_path = save_path + "important_mat_" + category_group + "_"+ file_name
      module.save_Draw_FeatureImportanceMatrix(patient_id_df,bestDT[3],cls[0], featureImportance_path, True)

    model_path = save_path + "bestModel_" + category_group + "_"+ file_name + ".joblib"
    joblib.dump(bestDT[4], model_path)

    df_evaluation_results[file_name] = bestDT[0]
    df_evaluation_results.to_csv(output_dir+patient_id+category_group+"/sklearn_models_balanced_for_train_metrics_"+category_group + ".csv")

# %%
def runner_decision_tree():
    ids = all_patient_data['id'].unique().tolist()
    for id in ids:
        patient_id = id + "/"
        file_name = id
        patient_id_df = all_patient_data[all_patient_data['id'] == id]
        filtered_df = patient_id_df.filter(REQUIRED_COLUMNS)
        patient_id_df = filtered_df.copy()
        
        # Decision Tree
        df_evaluation_results = pd.DataFrame(index=EVALUATION_METRICS)
        category_group = '1DecisionTree'
        cls = ["DecisionTree", sklearn.tree.DecisionTreeClassifier(max_depth=4)]
        classification_func(file_name, predictColumn, minorityVariable, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df)

def runner_knn():
    ids = all_patient_data['id'].unique().tolist()
    for id in ids:
        patient_id = id + "/"
        file_name = id
        patient_id_df = all_patient_data[all_patient_data['id'] == id]
        filtered_df = patient_id_df.filter(REQUIRED_COLUMNS)
        patient_id_df = filtered_df.copy()
        
        # KNN
        df_evaluation_results = pd.DataFrame(index=EVALUATION_METRICS)
        category_group = '2K-NN'
        cls = ["K-NN", sklearn.neighbors.KNeighborsClassifier()]
        classification_func(file_name, predictColumn, minorityVariable, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df)

def runner_lr():
    ids = all_patient_data['id'].unique().tolist()
    for id in ids:
        patient_id = id + "/"
        file_name = id
        patient_id_df = all_patient_data[all_patient_data['id'] == id]
        filtered_df = patient_id_df.filter(REQUIRED_COLUMNS)
        patient_id_df = filtered_df.copy()
        
        # Logistic Regression
        df_evaluation_results = pd.DataFrame(index=EVALUATION_METRICS)
        category_group = 'LogisticRegression'
        print(logit_reg_model)
        cls = ["Logit Regression", logit_reg_model]
        classification_func(file_name, predictColumn, minorityVariable, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df)

def runner_svm():
    ids = all_patient_data['id'].unique().tolist()
    for id in ids:
        patient_id = id + "/"
        file_name = id
        patient_id_df = all_patient_data[all_patient_data['id'] == id]
        filtered_df = patient_id_df.filter(REQUIRED_COLUMNS)
        patient_id_df = filtered_df.copy()
        
        # SVM
        df_evaluation_results = pd.DataFrame(index=EVALUATION_METRICS)
        category_group = 'SVM'
        cls = ["SVM", sklearn.svm.SVC(kernel="linear")]
        classification_func(file_name, predictColumn, minorityVariable, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df)

def runner_nb():
    ids = all_patient_data['id'].unique().tolist()
    for id in ids:
        patient_id = id + "/"
        file_name = id
        patient_id_df = all_patient_data[all_patient_data['id'] == id]
        filtered_df = patient_id_df.filter(REQUIRED_COLUMNS)
        patient_id_df = filtered_df.copy()
        
        # Naive Bayes
        df_evaluation_results = pd.DataFrame(index=EVALUATION_METRICS)
        category_group = 'NaiveBayes'
        cls = ["Naive Bayes", sklearn.gaussian_process.GaussianProcessClassifier()]
        classification_func(file_name, predictColumn, minorityVariable, category_group, cls, output_dir, df_evaluation_results, patient_id, patient_id_df)

# %%
runner_decision_tree()
# Out:
# ~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  125  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01030796580016613  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.011773115023970604  ~~~~~~~
# 2/2 [==============================] - 1s 13ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    86
# 0    78
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  164  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  125  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009755276143550873  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.013918748125433922  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    86
# 0    78
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  164  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  126  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009176133200526237  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.012631961144506931  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    90
# 0    72
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  162  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7558712121212121 DecisionTreeClassifier(max_depth=3)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=3)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=10)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=17)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 17, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.020188476890325546  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.028955882415175438  ~~~~~~~
# 1/1 [==============================] - 0s 454ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    91
# 0    58
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  149  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010569949634373188  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.0214027501642704  ~~~~~~~
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000208569FEC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 373ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    88
# 0    64
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  152  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011365446262061596  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.037310726940631866  ~~~~~~~
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020857C93790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 246ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    91
# 0    58
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  149  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6443678160919539 DecisionTreeClassifier(max_depth=5)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=5)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.6709677419354839 DecisionTreeClassifier(criterion='entropy', max_depth=16)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=16)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.7250574712643678 DecisionTreeClassifier(max_depth=4)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=4)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-008 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  118  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.007760611362755299  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.01613534614443779  ~~~~~~~
# 1/1 [==============================] - 0s 211ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    88
# 0    60
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  148  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  119  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.015625840052962303  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.035300929099321365  ~~~~~~~
# 1/1 [==============================] - 0s 143ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    98
# 0    42
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  140  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  119  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011818771250545979  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.015727674588561058  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    84
# 0    70
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  154  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8377011494252873 DecisionTreeClassifier(criterion='entropy', max_depth=16)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=16)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=20)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=18)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 18, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-011 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010246976278722286  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.024893639609217644  ~~~~~~~
# 2/2 [==============================] - 0s 12ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    98
# 0    84
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  182  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01272991206496954  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.019372815266251564  ~~~~~~~
# 2/2 [==============================] - 0s 13ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    100
# 0     80
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  180  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014852055348455906  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.024222880601882935  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    96
# 0    88
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  184  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.9178678678678678 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.9388888888888889 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=11)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 11, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-012 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  129  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014856847003102303  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.014035152271389961  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    89
# 0    80
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  169  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  129  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.008635085076093674  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.020676681771874428  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    90
# 0    78
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  168  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  130  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010891515761613846  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.01708008348941803  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    95
# 0    70
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  165  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7925133689839573 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=4)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-022 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  136  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01034741010516882  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.01941387727856636  ~~~~~~~
# 2/2 [==============================] - 0s 19ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    92
# 0    88
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  180  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  136  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009730463847517967  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.019024474546313286  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    94
# 0    84
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  178  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  136  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010096240788698196  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.020584525540471077  ~~~~~~~
# 2/2 [==============================] - 0s 11ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    100
# 0     72
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  172  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7833333333333334 DecisionTreeClassifier(max_depth=11)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=11)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=10)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-023 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  129  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.016242437064647675  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02633957378566265  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    90
# 1    84
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  174  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  129  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009095212444663048  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.015112568624317646  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    93
# 0    72
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  165  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  130  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011413018219172955  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02679097279906273  ~~~~~~~
# 2/2 [==============================] - 0s 7ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    91
# 0    78
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  169  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7065546218487395 DecisionTreeClassifier(max_depth=4)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=4)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.7272727272727273 DecisionTreeClassifier(criterion='entropy', max_depth=10)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=10)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.7449197860962566 DecisionTreeClassifier(max_depth=11)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=11)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 11, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-025 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  78  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.018843481317162514  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03873509541153908  ~~~~~~~
# 1/1 [==============================] - 0s 351ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    61
# 0    34
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  95  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  78  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.016675172373652458  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.027380913496017456  ~~~~~~~
# 1/1 [==============================] - 0s 293ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    61
# 0    34
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  95  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  78  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013357988558709621  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02833283320069313  ~~~~~~~
# 1/1 [==============================] - 0s 336ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    62
# 0    32
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  94  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7789473684210526 DecisionTreeClassifier(max_depth=18)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=18)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=15)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=14)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 14, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-028 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  61  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010779798030853271  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02285783737897873  ~~~~~~~
# 1/1 [==============================] - 0s 362ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    45
# 0    32
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  77  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  61  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013657680712640285  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.014424112625420094  ~~~~~~~
# 1/1 [==============================] - 0s 231ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    43
# 0    36
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  79  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  62  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014717526733875275  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.015768108889460564  ~~~~~~~
# 1/1 [==============================] - 0s 191ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    44
# 1    40
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  84  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8066666666666666 DecisionTreeClassifier(max_depth=4)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=4)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.8358333333333334 DecisionTreeClassifier(max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=15)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 15, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-033 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  35  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01723223365843296  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.015358706004917622  ~~~~~~~
# 1/1 [==============================] - 0s 230ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    34
# 1    18
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  52  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  35  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013786915689706802  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03740955516695976  ~~~~~~~
# 1/1 [==============================] - 0s 498ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    30
# 1    20
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  50  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  36  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.016433125361800194  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.045736826956272125  ~~~~~~~
# 1/1 [==============================] - 0s 421ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    28
# 1    22
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  50  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8654545454545456 DecisionTreeClassifier(max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=8)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-037 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.008464368991553783  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.018185550346970558  ~~~~~~~
# 2/2 [==============================] - 0s 11ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    100
# 0     80
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  180  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.016211017966270447  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.021250225603580475  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    94
# 0    92
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  186  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  140  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011878127232193947  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.016648098826408386  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    100
# 0     80
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  180  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6777777777777777 DecisionTreeClassifier(criterion='entropy', max_depth=5)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=5)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=4)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=5)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-043 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  127  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011371251195669174  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.011236242949962616  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    91
# 0    72
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  163  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  127  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.0133002158254385  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.018342815339565277  ~~~~~~~
# 1/1 [==============================] - 0s 325ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    97
# 0    60
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  157  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  128  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013753210194408894  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.013081115670502186  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    90
# 0    76
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  166  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8217803030303031 DecisionTreeClassifier(max_depth=3)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=3)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=17)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 17, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-056 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  127  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.02228008396923542  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03693542256951332  ~~~~~~~
# 1/1 [==============================] - 0s 274ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    106
# 0     42
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  148  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  127  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.012596077285706997  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02605891227722168  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    94
# 0    66
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  160  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  128  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013728157617151737  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02828049287199974  ~~~~~~~
# 1/1 [==============================] - 0s 209ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    100
# 0     56
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  156  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8190804597701149 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=3)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.8397177419354838 DecisionTreeClassifier(max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-059 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  135  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013389973901212215  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.021271396428346634  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    98
# 0    74
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  172  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  135  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009130851365625858  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.016266489401459694  ~~~~~~~
# 1/1 [==============================] - 0s 250ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    104
# 0     62
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  166  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  136  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014726088382303715  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.026680054143071175  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    102
# 0     68
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  170  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6805042016806723 DecisionTreeClassifier(criterion='entropy', max_depth=14)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=14)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.7409982174688057 DecisionTreeClassifier(criterion='entropy', max_depth=12)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=12)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=12)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 12, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-060 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  58  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01585879921913147  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.030085843056440353  ~~~~~~~
# 1/1 [==============================] - 0s 399ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    40
# 0    36
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  76  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  59  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.02682655118405819  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02511550858616829  ~~~~~~~
# 1/1 [==============================] - 0s 184ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    42
# 0    34
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  76  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  59  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.02177484706044197  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03195760399103165  ~~~~~~~
# 1/1 [==============================] - 0s 179ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    40
# 0    38
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  78  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6708333333333333 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.7641666666666667 DecisionTreeClassifier(criterion='entropy', max_depth=7)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=7)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=18)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 18, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-070 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  134  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010601519607007504  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.013732288964092731  ~~~~~~~
# 2/2 [==============================] - 0s 4ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    92
# 1    88
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  180  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  135  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.007930966094136238  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.018066909164190292  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    97
# 0    76
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  173  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  135  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.009516539052128792  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.017629349604249  ~~~~~~~
# 2/2 [==============================] - 0s 7ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    99
# 0    72
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  171  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7166666666666667 DecisionTreeClassifier(max_depth=22)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=22)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.7171428571428572 DecisionTreeClassifier(criterion='entropy', max_depth=17)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=17)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=18)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 18, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-071 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  82  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013573107309639454  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.017897162586450577  ~~~~~~~
# 1/1 [==============================] - 0s 172ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    68
# 0    28
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  96  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  83  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.015102016739547253  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03810298442840576  ~~~~~~~
# 1/1 [==============================] - 0s 191ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    72
# 0    22
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  94  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  83  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011241295374929905  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.024838004261255264  ~~~~~~~
# 1/1 [==============================] - 0s 231ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    70
# 0    26
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  96  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.8631578947368421 DecisionTreeClassifier(max_depth=5)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=5)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=16)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 16, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ...
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6612903225806452 DecisionTreeClassifier(max_depth=12)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=12)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.6794354838709676 DecisionTreeClassifier(criterion='entropy', max_depth=4)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=4)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.7554435483870968 DecisionTreeClassifier(criterion='entropy', max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=2)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-081 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  22  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.0168155524879694  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.04981023073196411  ~~~~~~~
# 1/1 [==============================] - 0s 245ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    15
# 0    14
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  29  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  23  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014025735668838024  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.04659763351082802  ~~~~~~~
# 1/1 [==============================] - 0s 246ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    22
# 1    12
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  34  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  23  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014513124711811543  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03217165172100067  ~~~~~~~
# 1/1 [==============================] - 0s 203ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    20
# 1    13
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  33  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7933333333333333 DecisionTreeClassifier(criterion='entropy', max_depth=11)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=11)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.9095238095238095 DecisionTreeClassifier(max_depth=7)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=7)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=22)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 22, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-082 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  91  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013634410686790943  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02161654829978943  ~~~~~~~
# 1/1 [==============================] - 0s 251ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    62
# 1    60
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  122  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  91  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01527568232268095  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02775382623076439  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    66
# 1    58
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  124  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  92  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.014672762714326382  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.022850312292575836  ~~~~~~~
# 2/2 [==============================] - 0s 6ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    80
# 1    52
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  132  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6646666666666666 DecisionTreeClassifier(max_depth=13)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=13)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.6843333333333333 DecisionTreeClassifier(criterion='entropy', max_depth=15)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=15)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.7341880341880341 DecisionTreeClassifier(criterion='entropy', max_depth=14)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=14)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 14, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-083 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  137  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010772611945867538  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.018638504669070244  ~~~~~~~
# 2/2 [==============================] - 0s 17ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    96
# 0    82
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  178  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  137  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01120310090482235  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.028041498735547066  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    95
# 0    84
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  179  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  138  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011601130478084087  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.015893148258328438  ~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    97
# 0    82
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  179  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.6857142857142857 DecisionTreeClassifier(max_depth=18)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=18)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.6926984126984127 DecisionTreeClassifier(max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 1-----------kfold--------------- 2 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=17)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 17, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-089 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  32  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.011022713035345078  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.055588770657777786  ~~~~~~~
# 1/1 [==============================] - 0s 207ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    24
# 0    16
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  40  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  33  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.01752055436372757  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02460821531713009  ~~~~~~~
# 1/1 [==============================] - 0s 344ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 0    26
# 1    20
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  46  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  33  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.00995162595063448  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.04369034245610237  ~~~~~~~
# 1/1 [==============================] - 0s 342ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    24
# 0    18
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  42  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.85 DecisionTreeClassifier(criterion='entropy', max_depth=18)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=18)
# * 0-----------kfold--------------- 1 ------------
# ----DecisionTree kfold---------- 0.8666666666666666 DecisionTreeClassifier(criterion='entropy', max_depth=17)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=17)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.8777777777777779 DecisionTreeClassifier(criterion='entropy', max_depth=4)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=4)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'entropy', 'max_depth': 4, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------
# ~~~~~~~~~~~~~~~~~ SB-112 ~~~~~~~~~~~~~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010879767127335072  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.03488393500447273  ~~~~~~~
# 1/1 [==============================] - 0s 279ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    94
# 0    52
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  146  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.010024706833064556  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.02139320783317089  ~~~~~~~
# 1/1 [==============================] - 0s 271ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    93
# 0    54
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  147  ~~~~~~~~~~
# ~~~~~~~~~~ Number of instances before balancing:  120  ~~~~~~~~~~
# ~~~~~~~ Training Loss: 0.013233926147222519  ~~~~~~~
# ~~~~~~~ Validation Loss: 0.031596943736076355  ~~~~~~~
# 1/1 [==============================] - 0s 194ms/step
# ~~~~~~~ value_counts: ~~~~~~~
# 1    95
# 0    50
# Name: class, dtype: int64
# ~~~~~~~~~~ Number of instances after balancing:  145  ~~~~~~~~~~
# ~~~~~~~~~~ DecisionTree ~~~~~~~~~~~~~~~
# -----------kfold--------------- 0 ------------
# ----DecisionTree kfold---------- 0.7466666666666667 DecisionTreeClassifier(criterion='entropy', max_depth=11)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(criterion='entropy', max_depth=11)
# * 0-----------kfold--------------- 1 ------------
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=7)
# * 1-----------kfold--------------- 2 ------------
# ----DecisionTree kfold---------- 0.7517241379310345 DecisionTreeClassifier(max_depth=2)
# There is Feature Importance matrix for this classifier: DecisionTreeClassifier(max_depth=2)
# * 2*
# {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 2, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': None, 'splitter': 'best'}
# ------run_cv runs successfully------------
# ++++++++++++save_confusion_matrix++++++++++++
# Classificationv3.py:353: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_xticklabels([''] + ['0', '1'], fontsize='xx-large')
# Classificationv3.py:354: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[i].set_yticklabels([''] + ['0', '1'], fontsize='xx-large')
# ++++++++++++save_confusion_matrix end++++++++++++
# (((((((((((((((((((((( draw droc ))))))))))))))))))))))))))))))
# (((((((( draw droc end ))))))))
# ---------------DrawFeatureImportanceMatrix------------
# ------------DrawFeatureImportanceMatrix end----------------

# %%
# runner_knn()

# %%
# runner_lr()

# %%
# runner_svm()

# %%
# runner_nb()
