# %%
'''
TOP 5 BALANCED MODELS

Type	Model	Loss	Validation Loss	Total Area	Avg KL div
Balanced	L27_E22_20_B16_D20_22	0.005998428	0.006721942	1.678734815	0.043755358
Balanced	L27_E22_20_B18_D18_20	0.006337718	0.007222764	1.67867217	0.046867523
Balanced	L27_E20_18_B18_D14_16	0.007929437	0.008441048	1.669568182	0.047048626
Balanced	L27_E20_18_B16_D20_22	0.007419921	0.008254252	1.703921669	0.048325082
Balanced	L27_E22_20_B18_D20_22	0.007805503	0.008784806	1.723715099	0.049680205
'''

# Notebook for : L27_E22_20_B16_D20_22
# Out:
# '\nTOP 5 BALANCED MODELS\n\nType\tModel\tLoss\tValidation Loss\tTotal Area\tAvg KL div\nBalanced\tL27_E22_20_B16_D20_22\t0.005998428\t0.006721942\t1.678734815\t0.043755358\nBalanced\tL27_E22_20_B18_D18_20\t0.006337718\t0.007222764\t1.67867217\t0.046867523\nBalanced\tL27_E20_18_B18_D14_16\t0.007929437\t0.008441048\t1.669568182\t0.047048626\nBalanced\tL27_E20_18_B16_D20_22\t0.007419921\t0.008254252\t1.703921669\t0.048325082\nBalanced\tL27_E22_20_B18_D20_22\t0.007805503\t0.008784806\t1.723715099\t0.049680205\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import gaussian_kde, entropy

# %%
original_df = pd.read_csv("L27_E22_20_B16_D20_22_Original_minority_data.csv")   
original_df.drop('class', axis=1, inplace=True)
synthetic_df = pd.read_csv("L27_E22_20_B16_D20_22_Synthetic_minority_data.csv") 
synthetic_df.drop('class', axis=1, inplace=True)

# %%
class Duplicates:
    def __init__(self, original_df, synthetic_df):
        self.original_df = original_df
        self.synthetic_df = synthetic_df
        self.combined_df = pd.concat([self.original_df, self.synthetic_df], axis=0)

        if self.original_df.shape[1] != self.synthetic_df.shape[1]:
            raise Exception("The number of columns in the original and synthetic datasets must match, but they are different ", self.original_df.shape[1], self.synthetic_df.shape[1])
        
        if self.original_df.shape[0] != self.synthetic_df.shape[0]:
            raise Exception("The number of rows in the original and synthetic datasets are different ", self.original_df.shape[0], self.synthetic_df.shape[0])
        
    def identify_duplicates(self):
        num_duplicates_original_df = self.original_df.duplicated().sum()
        num_duplicates_synthetic_df = self.synthetic_df.duplicated().sum()
        rows_present_in_original = self.synthetic_df.isin(self.original_df.to_dict(orient='list')).all(axis=1)
        num_rows_present = rows_present_in_original.sum()

        print("Number of duplicates in original_df:", num_duplicates_original_df)
        print("Number of duplicates in synthetic_df:", num_duplicates_synthetic_df)
        print("Number of rows in synthetic_df present in original_df:", num_rows_present)    

    
    def calculate_similarity(self, threshold):
        #A row is said to be similar, if all the values of the different columns 
        # in that row are within threshold% deviation of the values in same columns for a different row. 
        def get_similar_df(df1, threshold, **kwargs):

            df2 = kwargs.get('df2', None)
            if df2 is None:
                df2 = df1.copy()

            similar_rows_count = 0
            #similar_rows = []
            for i in range(len(df1)):
                for j in range(i+1, len(df1)):
                    row1, row2 = df1.iloc[i], df2.iloc[j]

                    if (row1 == 0).any() or (row2 == 0).any() or (row1.isna().any()) or (row2.isna().any()):
                        continue

                    deviation = abs((row1 - row2) / row1)
                    if (deviation <= threshold).all():
                        #similar_rows.append((row1.values, row2.values))
                        similar_rows_count += 1             
            return similar_rows_count    

        original_df_similarity = get_similar_df(self.original_df, threshold)
        print(f"Total number of similar rows in original_df: {original_df_similarity}")
        print(f"Duplicate ratio in original_df: {original_df_similarity / self.original_df.shape[0]:.3f}")

        synthetic_df_similarity = get_similar_df(self.synthetic_df, threshold)
        print(f"Total number of similar rows in synthetic_df: {synthetic_df_similarity}")
        print(f"Duplicate ratio in synthetic_df: {synthetic_df_similarity / self.synthetic_df.shape[0]:.3f}")

        synthetic_original_similarity = get_similar_df(self.original_df, threshold, df2=self.synthetic_df)
        print(f"Total number of similar synthetic_df rows in original_df: {synthetic_original_similarity}")
        print(f"Duplicate ratio in similar synthetic_df rows in original_df: {synthetic_original_similarity / self.combined_df.shape[0]:.3f}")

class Analyze:
    def __init__(self, original_df, synthetic_df):
        self.df1 = original_df
        self.df2 = synthetic_df

        if self.df1.shape[1] != self.df2.shape[1]:
            raise Exception("The number of columns in the original and synthetic datasets must match")
        
        if self.df1.shape[0] != self.df2.shape[0]:
            raise Exception("The number of rows in the original and synthetic datasets are different ", self.df1.shape[0], self.df2.shape[0])

    def meanAndStd(self) -> pd.DataFrame:
        output = {}
        for column in self.df1.columns:
            mean_df1 = self.df1[column].mean()
            std_df1  = self.df1[column].std()
            mean_df2 = self.df2[column].mean()
            std_df2  = self.df2[column].std()
            meandiff = abs(mean_df1 - mean_df2)

            output[column] = {'Mean_diff': meandiff,
                            'Mean_original_df': mean_df1, 'Mean_synthetic_df': mean_df2,
                            'Std_original_df' : std_df1,  'Std_synthetic_df' : std_df2}
        return pd.DataFrame(output).transpose().sort_values(by='Mean_diff', ascending=False)
    
    def plotHeatMaps(self,annot=False) -> None:
        _ , axes = plt.subplots(1, 2, figsize=(18, 10))
        sns.heatmap(self.df1.corr(), annot=annot, cmap='viridis', ax=axes[0])
        axes[0].set_title('Original')

        sns.heatmap(self.df2.corr(), annot=annot, cmap='viridis', ax=axes[1])
        axes[1].set_title('Synthetic')
        plt.tight_layout()
        plt.show()

    def plotScatterPlots(self, start_index, end_index) -> None:
        num_columns = len(self.df1.columns)
        num_rows = (num_columns + 4) // 5  

        fig, axs = plt.subplots(num_rows, 5, figsize=(15, num_rows * 3))
        for i, column in enumerate(self.df1.columns):
            row_idx = i // 5
            col_idx = i % 5

            axs[row_idx, col_idx].scatter(self.df1.index[start_index:end_index], self.df1[column][start_index:end_index], color='red', label='original_df')
            axs[row_idx, col_idx].scatter(self.df2.index[start_index:end_index], self.df2[column][start_index:end_index], color='blue', label='synthetic_df')

            axs[row_idx, col_idx].set_title(f"Scatter Plot: {column}")
            axs[row_idx, col_idx].set_xlabel("Index")
            axs[row_idx, col_idx].set_ylabel(column)

            axs[row_idx, col_idx].legend()

        for i in range(num_columns, num_rows * 5):
            row_idx = i // 5
            col_idx = i % 5
            fig.delaxes(axs[row_idx, col_idx])

        plt.tight_layout()
        plt.show()

        for i in range(num_columns, num_rows * 5):
            row_idx = i // 5
            col_idx = i % 5
            fig.delaxes(axs[row_idx, col_idx])

        plt.tight_layout()
        plt.show()
    

    def plot_density(self):
        num_columns = len(self.df2.columns)
        num_rows = int(np.ceil(num_columns / 5))
        fig, axes = plt.subplots(num_rows, 5, figsize=(20, 4 * num_rows))

        highlighted_areas = {} 
        kl_divergences = {}  

        for i, column in enumerate(self.df1.columns):
            row = i // 5
            col = i % 5
            ax = axes[row, col] if num_rows > 1 else axes[col]

            sns.kdeplot(data=self.df1[column], color='blue', label='original_df', ax=ax)
            sns.kdeplot(data=self.df2[column], color='green', label='synthetic_df', ax=ax)

            # Fill between the curves
            x = np.linspace(0, 1, 1000)  
            kde_original = gaussian_kde(self.df1[column])
            kde_synthetic = gaussian_kde(self.df2[column])
            y1 = kde_original(x)
            y2 = kde_synthetic(x)
            ax.fill_between(x, y1, y2, where=(y1 > y2), interpolate=True, color='lightcoral', alpha=0.3)
            ax.fill_between(x, y1, y2, where=(y1 <= y2), interpolate=True, color='lightgreen', alpha=0.3)

            # Calculate and store the highlighted area for the column
            highlighted_area = np.sum(np.maximum(y1 - y2, 0) * np.diff(x)[0])
            highlighted_areas[column] = highlighted_area

            # Calculate and store the KL divergence for the column
            kl_divergence = entropy(y1, y2) # REF https://www.kaggle.com/code/nhan1212/some-statistical-distances
            kl_divergences[column] = kl_divergence

            ax.set_title(column)
            ax.set_xlabel(column)
            ax.set_xlim(0, 1)
            ax.legend()

        plt.tight_layout()
        plt.show()

        total_highlighted_area = np.sum(list(highlighted_areas.values()))
        total_kl_divergence = np.sum(list(kl_divergences.values()))

        for column, area in highlighted_areas.items():
            divergence = kl_divergences[column]
            print(f"{column}: {area:.2f}, {divergence:.6f}")

        print(f"Total highlighted area: {total_highlighted_area:.2f}")
        print(f"Average KL divergence: {total_kl_divergence / num_columns:.6f}")

# %%
dup = Duplicates(original_df, synthetic_df)
dup.identify_duplicates()
# Out:
# Number of duplicates in original_df: 1
# Number of duplicates in synthetic_df: 1
# Number of rows in synthetic_df present in original_df: 0

# %%
dup.calculate_similarity(threshold=0.1)
# Out:
# Total number of similar rows in original_df: 1
# Duplicate ratio in original_df: 0.001
# Total number of similar rows in synthetic_df: 1
# Duplicate ratio in synthetic_df: 0.001
# Total number of similar synthetic_df rows in original_df: 0
# Duplicate ratio in similar synthetic_df rows in original_df: 0.000

# %%
dup.calculate_similarity(threshold=0.25)
# Out:
# Total number of similar rows in original_df: 1
# Duplicate ratio in original_df: 0.001
# Total number of similar rows in synthetic_df: 3
# Duplicate ratio in synthetic_df: 0.003
# Total number of similar synthetic_df rows in original_df: 0
# Duplicate ratio in similar synthetic_df rows in original_df: 0.000

# %%
dup.calculate_similarity(threshold=0.50)
# Out:
# Total number of similar rows in original_df: 18
# Duplicate ratio in original_df: 0.016
# Total number of similar rows in synthetic_df: 289
# Duplicate ratio in synthetic_df: 0.254
# Total number of similar synthetic_df rows in original_df: 24
# Duplicate ratio in similar synthetic_df rows in original_df: 0.011

# %%
obj = Analyze(original_df, synthetic_df)
obj.plot_density()
# Out:
# income: 0.06, 0.032142
# road_dist: 0.04, 0.025005
# cooking: 0.09, 0.045250
# y_am_pef: 0.06, 0.019677
# tempin: 0.14, 0.311989
# humidin: 0.03, 0.015761
# pm25in: 0.07, 0.032037
# co2in: 0.11, 0.137597
# tempdiffin: 0.04, 0.018537
# humidiffin: 0.07, 0.035618
# pm25diffin: 0.06, 0.049431
# pm10: 0.10, 0.055352
# pm25: 0.08, 0.026955
# o3: 0.04, 0.051669
# no2: 0.07, 0.025550
# co: 0.07, 0.030340
# so2: 0.07, 0.049712
# temp: 0.05, 0.018356
# windsd: 0.06, 0.029531
# humid: 0.03, 0.009266
# varp: 0.05, 0.022369
# dewpt: 0.05, 0.012693
# airp: 0.07, 0.051869
# seap: 0.07, 0.046710
# solrhr: 0.03, 0.007494
# solramnt: 0.04, 0.012987
# grdt: 0.03, 0.007498
# Total highlighted area: 1.68
# Average KL divergence: 0.043755

# %%
obj.plotHeatMaps(annot=False)

# %%
obj.meanAndStd()
# Out:
#             Mean_diff  Mean_original_df  Mean_synthetic_df  Std_original_df  \
# pm10         0.019630          0.364241           0.344611         0.214467
# humidiffin   0.015521          0.505331           0.520851         0.215609
# varp         0.014532          0.293001           0.278469         0.212729
# dewpt        0.013117          0.541337           0.528220         0.217559
# solramnt     0.012948          0.383861           0.370913         0.269445
# y_am_pef     0.011347          0.429845           0.418498         0.234906
# humid        0.010868          0.467403           0.456535         0.241009
# no2          0.010080          0.337537           0.327457         0.220364
# road_dist    0.009513          0.681179           0.671666         0.337865
# so2          0.007920          0.316427           0.308507         0.228177
# co           0.007690          0.315620           0.323310         0.215182
# grdt         0.007640          0.472785           0.465146         0.245139
# income       0.007512          0.627994           0.635506         0.286453
# tempdiffin   0.006647          0.448667           0.442020         0.225820
# co2in        0.005688          0.387642           0.381954         0.211551
# cooking      0.004706          0.413335           0.408629         0.276375
# pm25         0.004296          0.272375           0.268079         0.207945
# windsd       0.004045          0.337500           0.341545         0.231418
# solrhr       0.003601          0.463676           0.467277         0.299326
# airp         0.003181          0.551900           0.555081         0.219497
# tempin       0.002649          0.508105           0.505456         0.219289
# pm25in       0.002597          0.311463           0.314060         0.207300
# o3           0.002274          0.339090           0.341364         0.202895
# pm25diffin   0.001659          0.579442           0.581100         0.184006
# humidin      0.000731          0.426543           0.427274         0.224278
# seap         0.000166          0.548227           0.548061         0.219533
# temp         0.000040          0.545384           0.545424         0.222087
#
#             Std_synthetic_df
# pm10                0.191526
# humidiffin          0.200534
# varp                0.203719
# dewpt               0.212925
# solramnt            0.251998
# y_am_pef            0.224722
# humid               0.228911
# no2                 0.204285
# road_dist           0.329858
# so2                 0.198377
# co                  0.201160
# grdt                0.239827
# income              0.268976
# tempdiffin          0.215231
# co2in               0.163493
# cooking             0.254123
# pm25                0.198035
# windsd              0.212969
# solrhr              0.286943
# airp                0.198155
# tempin              0.164828
# pm25in              0.190927
# o3                  0.175184
# pm25diffin          0.159995
# humidin             0.206701
# seap                0.201271
# temp                0.214427

# %%
#%%capture
#!pip install -U gretel-client

from gretel_client.config import RunnerMode
from gretel_client.evaluation.quality_report import QualityReport
from gretel_client import configure_session


# Specify your Gretel API Key

pd.set_option("max_colwidth", None)
configure_session(api_key="prompt", cache="yes", validate=True)

# Create a Quality Report
report = QualityReport(data_source=synthetic_df, ref_data=original_df)
print(report.run())

# Synthetic Data Quality Score (SQS)
print(report.peek())
# Out:
# Config file C:\Users\sbhuv\.gretel\config.json is group- and/or world-readable!
# Setting permissions to be readable by the owner only.
# Config file C:\Users\sbhuv\.gretel\config.json is group- and/or world-readable!
# Setting permissions to be readable by the owner only.
# Config file C:\Users\sbhuv\.gretel\config.json is group- and/or world-readable!
# Setting permissions to be readable by the owner only.
# Using endpoint https://api.gretel.cloud
# Logged in as sbhuvaj@gmail.com ✅
# None
# {'raw_score': 83.82962962962962, 'grade': 'Excellent', 'score': 83}

# %%
report.as_dict
# Out:
# {'left_rows': 1137,
#  'left_cols': 27,
#  'right_rows': 1137,
#  'right_cols': 27,
#  'fields': [{'name': 'cooking',
#    'left_field_features': {'name': 'cooking',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 7,
#     'unique_percent': 0.6157,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.5339,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'cooking',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.6482,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.118, 0.176]': 0.20492524186455585,
#     '(-0.001, 0.0588]': 0.07036059806508356,
#     '(0.647, 0.706]': 0.1284080914687775,
#     '(0.294, 0.353]': 0.3975373790677221,
#     '(0.941, 1.0]': 0.09938434476693052,
#     '(0.471, 0.529]': 0.0633245382585752,
#     '(0.824, 0.882]': 0.03605980650835532},
#    'right_distribution': {'(0.294, 0.353]': 0.12752858399296393,
#     '(0.118, 0.176]': 0.08970976253298153,
#     '(0.824, 0.882]': 0.027264731750219876,
#     '(0.353, 0.412]': 0.06684256816182937,
#     '(0.0588, 0.118]': 0.06948109058927,
#     '(0.235, 0.294]': 0.1627088830255057,
#     '(0.412, 0.471]': 0.04925241864555849,
#     '(0.765, 0.824]': 0.030782761653474055,
#     '(0.882, 0.941]': 0.06948109058927,
#     '(0.471, 0.529]': 0.0395778364116095,
#     '(0.176, 0.235]': 0.11961301671064203,
#     '(0.588, 0.647]': 0.025505716798592787,
#     '(0.529, 0.588]': 0.02198768689533861,
#     '(0.647, 0.706]': 0.040457343887423045,
#     '(0.706, 0.765]': 0.04221635883905013,
#     '(0.941, 1.0]': 0.016710642040457344,
#     '(-0.001, 0.0588]': 0.0008795074758135445},
#    'distribution_distance': 0.6882799016591717,
#    'distribution_stability': {'raw_score': 0.6882799016591717,
#     'grade': 'Poor',
#     'score': 23}},
#   {'name': 'solramnt',
#    'left_field_features': {'name': 'solramnt',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 613,
#     'unique_percent': 53.9138,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8399,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'solramnt',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.7194,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0625]': 0.0712401055408971,
#     '(0.875, 0.938]': 0.03342128408091469,
#     '(0.0625, 0.125]': 0.1169744942832014,
#     '(0.812, 0.875]': 0.04309586631486367,
#     '(0.562, 0.625]': 0.058927000879507474,
#     '(0.688, 0.75]': 0.026385224274406333,
#     '(0.188, 0.25]': 0.1284080914687775,
#     '(0.375, 0.438]': 0.056288478452066845,
#     '(0.75, 0.812]': 0.04397537379067722,
#     '(0.625, 0.688]': 0.047493403693931395,
#     '(0.125, 0.188]': 0.10642040457343888,
#     '(0.25, 0.312]': 0.08179419525065963,
#     '(0.312, 0.375]': 0.0633245382585752,
#     '(0.938, 1.0]': 0.023746701846965697,
#     '(0.438, 0.5]': 0.05013192612137203,
#     '(0.5, 0.562]': 0.048372911169744945},
#    'right_distribution': {'(0.0625, 0.125]': 0.11609498680738786,
#     '(0.875, 0.938]': 0.022867194371152155,
#     '(0.125, 0.188]': 0.09850483729111698,
#     '(0.75, 0.812]': 0.05013192612137203,
#     '(0.562, 0.625]': 0.04221635883905013,
#     '(0.688, 0.75]': 0.03518029903254178,
#     '(-0.001, 0.0625]': 0.07563764291996482,
#     '(0.188, 0.25]': 0.09586631486367635,
#     '(0.5, 0.562]': 0.05980650835532102,
#     '(0.375, 0.438]': 0.058927000879507474,
#     '(0.25, 0.312]': 0.12576956904133685,
#     '(0.625, 0.688]': 0.036939313984168866,
#     '(0.812, 0.875]': 0.052770448548812667,
#     '(0.312, 0.375]': 0.07387862796833773,
#     '(0.438, 0.5]': 0.055408970976253295},
#    'distribution_distance': 0.1453351899833642,
#    'distribution_stability': {'raw_score': 0.1453351899833642,
#     'grade': 'Excellent',
#     'score': 80}},
#   {'name': 'dewpt',
#    'left_field_features': {'name': 'dewpt',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 515,
#     'unique_percent': 45.2946,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8927,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'dewpt',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.4978,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.933, 1.0]': 0.023746701846965697,
#     '(0.6, 0.667]': 0.10202286719437115,
#     '(0.667, 0.733]': 0.10554089709762533,
#     '(0.733, 0.8]': 0.08179419525065963,
#     '(0.267, 0.333]': 0.07299912049252419,
#     '(0.2, 0.267]': 0.04573438874230431,
#     '(0.533, 0.6]': 0.1248900615655233,
#     '(0.8, 0.867]': 0.06772207563764292,
#     '(-0.001, 0.0667]': 0.01759014951627089,
#     '(0.0667, 0.133]': 0.016710642040457344,
#     '(0.467, 0.533]': 0.1169744942832014,
#     '(0.867, 0.933]': 0.02990325417766051,
#     '(0.133, 0.2]': 0.04397537379067722,
#     '(0.333, 0.4]': 0.06772207563764292,
#     '(0.4, 0.467]': 0.08267370272647317},
#    'right_distribution': {'(0.933, 1.0]': 0.008795074758135445,
#     '(0.6, 0.667]': 0.11081794195250659,
#     '(0.667, 0.733]': 0.09586631486367635,
#     '(0.267, 0.333]': 0.08795074758135445,
#     '(0.533, 0.6]': 0.10466138962181179,
#     '(0.8, 0.867]': 0.056288478452066845,
#     '(0.0667, 0.133]': 0.019349164467897976,
#     '(0.133, 0.2]': 0.05716798592788039,
#     '(0.4, 0.467]': 0.09410729991204925,
#     '(0.867, 0.933]': 0.04309586631486367,
#     '(0.333, 0.4]': 0.07563764291996482,
#     '(0.2, 0.267]': 0.05804749340369393,
#     '(0.733, 0.8]': 0.09058927000879508,
#     '(0.467, 0.533]': 0.09762532981530343},
#    'distribution_distance': 0.12843209839458591,
#    'distribution_stability': {'raw_score': 0.12843209839458591,
#     'grade': 'Excellent',
#     'score': 82}},
#   {'name': 'co2in',
#    'left_field_features': {'name': 'co2in',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 584,
#     'unique_percent': 51.3632,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8487,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'co2in',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.6271,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.0625, 0.125]': 0.04925241864555849,
#     '(0.625, 0.688]': 0.056288478452066845,
#     '(0.375, 0.438]': 0.10729991204925242,
#     '(0.188, 0.25]': 0.10290237467018469,
#     '(0.438, 0.5]': 0.08883025505716799,
#     '(0.688, 0.75]': 0.032541776605101144,
#     '(0.938, 1.0]': 0.011433597185576077,
#     '(-0.001, 0.0625]': 0.04573438874230431,
#     '(0.25, 0.312]': 0.12049252418645559,
#     '(0.312, 0.375]': 0.11873350923482849,
#     '(0.125, 0.188]': 0.08355321020228672,
#     '(0.5, 0.562]': 0.08443271767810026,
#     '(0.75, 0.812]': 0.02198768689533861,
#     '(0.562, 0.625]': 0.052770448548812667,
#     '(0.812, 0.875]': 0.018469656992084433,
#     '(0.875, 0.938]': 0.005277044854881266},
#    'right_distribution': {'(0.312, 0.375]': 0.1521547933157432,
#     '(0.375, 0.438]': 0.11081794195250659,
#     '(0.25, 0.312]': 0.15127528583992964,
#     '(0.438, 0.5]': 0.10202286719437115,
#     '(0.812, 0.875]': 0.0079155672823219,
#     '(0.188, 0.25]': 0.13896218117854,
#     '(0.125, 0.188]': 0.079155672823219,
#     '(0.562, 0.625]': 0.06860158311345646,
#     '(0.5, 0.562]': 0.0870712401055409,
#     '(0.625, 0.688]': 0.03869832893579595,
#     '(0.688, 0.75]': 0.030782761653474055,
#     '(0.75, 0.812]': 0.010554089709762533,
#     '(0.0625, 0.125]': 0.02198768689533861},
#    'distribution_distance': 0.21255831330102717,
#    'distribution_stability': {'raw_score': 0.21255831330102717,
#     'grade': 'Good',
#     'score': 71}},
#   {'name': 'road_dist',
#    'left_field_features': {'name': 'road_dist',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 5,
#     'unique_percent': 0.4398,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 4,
#     'avg_str_length': 3.3026,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 2},
#    'right_field_features': {'name': 'road_dist',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.5057,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0625]': 0.05804749340369393,
#     '(0.938, 1.0]': 0.45382585751978893,
#     '(0.188, 0.25]': 0.18469656992084432,
#     '(0.438, 0.5]': 0.18557607739665788,
#     '(0.688, 0.75]': 0.11785400175901495},
#    'right_distribution': {'(0.0625, 0.125]': 0.04309586631486367,
#     '(0.938, 1.0]': 0.3737906772207564,
#     '(0.188, 0.25]': 0.10817941952506596,
#     '(0.25, 0.312]': 0.055408970976253295,
#     '(0.438, 0.5]': 0.08179419525065963,
#     '(0.875, 0.938]': 0.1011433597185576,
#     '(-0.001, 0.0625]': 0.014951627088830254,
#     '(0.625, 0.688]': 0.008795074758135445,
#     '(0.75, 0.812]': 0.0316622691292876,
#     '(0.375, 0.438]': 0.04221635883905013,
#     '(0.688, 0.75]': 0.03518029903254178,
#     '(0.5, 0.562]': 0.04661389621811785,
#     '(0.562, 0.625]': 0.008795074758135445,
#     '(0.125, 0.188]': 0.016710642040457344,
#     '(0.812, 0.875]': 0.022867194371152155,
#     '(0.312, 0.375]': 0.008795074758135445},
#    'distribution_distance': 0.4948365926626943,
#    'distribution_stability': {'raw_score': 0.4948365926626943,
#     'grade': 'Poor',
#     'score': 38}},
#   {'name': 'seap',
#    'left_field_features': {'name': 'seap',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 529,
#     'unique_percent': 46.5259,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8584,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'seap',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.5233,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0667]': 0.025505716798592787,
#     '(0.4, 0.467]': 0.1310466138962181,
#     '(0.333, 0.4]': 0.0633245382585752,
#     '(0.867, 0.933]': 0.06860158311345646,
#     '(0.533, 0.6]': 0.10554089709762533,
#     '(0.6, 0.667]': 0.10202286719437115,
#     '(0.8, 0.867]': 0.04925241864555849,
#     '(0.933, 1.0]': 0.018469656992084433,
#     '(0.267, 0.333]': 0.04221635883905013,
#     '(0.733, 0.8]': 0.07299912049252419,
#     '(0.467, 0.533]': 0.1248900615655233,
#     '(0.667, 0.733]': 0.10554089709762533,
#     '(0.133, 0.2]': 0.032541776605101144,
#     '(0.2, 0.267]': 0.044854881266490766,
#     '(0.0667, 0.133]': 0.013192612137203167},
#    'right_distribution': {'(0.0667, 0.133]': 0.0158311345646438,
#     '(0.4, 0.467]': 0.11873350923482849,
#     '(0.333, 0.4]': 0.07299912049252419,
#     '(0.467, 0.533]': 0.09410729991204925,
#     '(0.867, 0.933]': 0.028144239226033423,
#     '(0.533, 0.6]': 0.1169744942832014,
#     '(0.733, 0.8]': 0.11081794195250659,
#     '(0.8, 0.867]': 0.08355321020228672,
#     '(0.2, 0.267]': 0.051890941072999124,
#     '(0.667, 0.733]': 0.11257695690413369,
#     '(0.6, 0.667]': 0.09058927000879508,
#     '(0.267, 0.333]': 0.06772207563764292,
#     '(0.133, 0.2]': 0.03605980650835532},
#    'distribution_distance': 0.1984976471965974,
#    'distribution_stability': {'raw_score': 0.1984976471965974,
#     'grade': 'Good',
#     'score': 72}},
#   {'name': 'solrhr',
#    'left_field_features': {'name': 'solrhr',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 385,
#     'unique_percent': 33.861,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.7142,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'solrhr',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 12,
#     'avg_str_length': 9.7027,
#     'min_value': 0.001,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 10},
#    'left_distribution': {'(-0.001, 0.0714]': 0.158311345646438,
#     '(0.929, 1.0]': 0.05452946350043975,
#     '(0.143, 0.214]': 0.044854881266490766,
#     '(0.714, 0.786]': 0.09762532981530343,
#     '(0.286, 0.357]': 0.05452946350043975,
#     '(0.643, 0.714]': 0.10290237467018469,
#     '(0.571, 0.643]': 0.07475813544415127,
#     '(0.357, 0.429]': 0.07036059806508356,
#     '(0.0714, 0.143]': 0.06420404573438875,
#     '(0.786, 0.857]': 0.06684256816182937,
#     '(0.5, 0.571]': 0.05452946350043975,
#     '(0.857, 0.929]': 0.03342128408091469,
#     '(0.429, 0.5]': 0.07475813544415127,
#     '(0.214, 0.286]': 0.048372911169744945},
#    'right_distribution': {'(-0.001, 0.0714]': 0.10202286719437115,
#     '(0.857, 0.929]': 0.09674582233948989,
#     '(0.0714, 0.143]': 0.09674582233948989,
#     '(0.786, 0.857]': 0.05716798592788039,
#     '(0.714, 0.786]': 0.08267370272647317,
#     '(0.429, 0.5]': 0.0712401055408971,
#     '(0.143, 0.214]': 0.06508355321020229,
#     '(0.571, 0.643]': 0.0853122251539138,
#     '(0.643, 0.714]': 0.09498680738786279,
#     '(0.214, 0.286]': 0.05804749340369393,
#     '(0.286, 0.357]': 0.058927000879507474,
#     '(0.357, 0.429]': 0.05452946350043975,
#     '(0.5, 0.571]': 0.06948109058927,
#     '(0.929, 1.0]': 0.007036059806508356},
#    'distribution_distance': 0.1939950908284296,
#    'distribution_stability': {'raw_score': 0.1939950908284296,
#     'grade': 'Good',
#     'score': 73}},
#   {'name': 'windsd',
#    'left_field_features': {'name': 'windsd',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 457,
#     'unique_percent': 40.1935,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8505,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'windsd',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.7318,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.235, 0.294]': 0.13016710642040458,
#     '(0.353, 0.412]': 0.09410729991204925,
#     '(0.118, 0.176]': 0.12049252418645559,
#     '(0.706, 0.765]': 0.022867194371152155,
#     '(0.0588, 0.118]': 0.09850483729111698,
#     '(0.588, 0.647]': 0.03781882145998241,
#     '(0.412, 0.471]': 0.07563764291996482,
#     '(0.176, 0.235]': 0.10026385224274406,
#     '(-0.001, 0.0588]': 0.05804749340369393,
#     '(0.765, 0.824]': 0.018469656992084433,
#     '(0.647, 0.706]': 0.024626209322779244,
#     '(0.471, 0.529]': 0.04573438874230431,
#     '(0.294, 0.353]': 0.10290237467018469,
#     '(0.824, 0.882]': 0.019349164467897976,
#     '(0.882, 0.941]': 0.01759014951627089,
#     '(0.529, 0.588]': 0.0158311345646438,
#     '(0.941, 1.0]': 0.01759014951627089},
#    'right_distribution': {'(0.294, 0.353]': 0.1011433597185576,
#     '(0.235, 0.294]': 0.13280562884784522,
#     '(0.118, 0.176]': 0.13016710642040458,
#     '(0.765, 0.824]': 0.02990325417766051,
#     '(0.0588, 0.118]': 0.10642040457343888,
#     '(0.176, 0.235]': 0.13192612137203166,
#     '(0.706, 0.765]': 0.029023746701846966,
#     '(0.588, 0.647]': 0.04397537379067722,
#     '(-0.001, 0.0588]': 0.014072119613016711,
#     '(0.471, 0.529]': 0.032541776605101144,
#     '(0.412, 0.471]': 0.06244503078276165,
#     '(0.529, 0.588]': 0.03605980650835532,
#     '(0.647, 0.706]': 0.03342128408091469,
#     '(0.353, 0.412]': 0.0870712401055409,
#     '(0.824, 0.882]': 0.022867194371152155,
#     '(0.882, 0.941]': 0.006156552330694811},
#    'distribution_distance': 0.17133270377199894,
#    'distribution_stability': {'raw_score': 0.17133270377199894,
#     'grade': 'Good',
#     'score': 76}},
#   {'name': 'humid',
#    'left_field_features': {'name': 'humid',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 549,
#     'unique_percent': 48.285,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8566,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'humid',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.5866,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.938, 1.0]': 0.03781882145998241,
#     '(0.25, 0.312]': 0.09762532981530343,
#     '(0.562, 0.625]': 0.055408970976253295,
#     '(0.625, 0.688]': 0.08267370272647317,
#     '(0.312, 0.375]': 0.09850483729111698,
#     '(0.375, 0.438]': 0.09762532981530343,
#     '(0.812, 0.875]': 0.03342128408091469,
#     '(0.0625, 0.125]': 0.03781882145998241,
#     '(0.75, 0.812]': 0.058927000879507474,
#     '(0.688, 0.75]': 0.052770448548812667,
#     '(0.5, 0.562]': 0.06948109058927,
#     '(0.875, 0.938]': 0.020228671943711522,
#     '(-0.001, 0.0625]': 0.023746701846965697,
#     '(0.438, 0.5]': 0.08619173262972735,
#     '(0.188, 0.25]': 0.08795074758135445,
#     '(0.125, 0.188]': 0.05980650835532102},
#    'right_distribution': {'(0.938, 1.0]': 0.0043975373790677225,
#     '(0.25, 0.312]': 0.10290237467018469,
#     '(0.562, 0.625]': 0.06948109058927,
#     '(0.188, 0.25]': 0.11081794195250659,
#     '(0.312, 0.375]': 0.09058927000879508,
#     '(0.375, 0.438]': 0.10202286719437115,
#     '(0.812, 0.875]': 0.048372911169744945,
#     '(0.125, 0.188]': 0.07299912049252419,
#     '(0.875, 0.938]': 0.03342128408091469,
#     '(0.75, 0.812]': 0.055408970976253295,
#     '(0.688, 0.75]': 0.0633245382585752,
#     '(-0.001, 0.0625]': 0.0008795074758135445,
#     '(0.5, 0.562]': 0.07299912049252419,
#     '(0.438, 0.5]': 0.07299912049252419,
#     '(0.0625, 0.125]': 0.04309586631486367,
#     '(0.625, 0.688]': 0.056288478452066845},
#    'distribution_distance': 0.16624712565819516,
#    'distribution_stability': {'raw_score': 0.16624712565819516,
#     'grade': 'Good',
#     'score': 77}},
#   {'name': 'so2',
#    'left_field_features': {'name': 'so2',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 30,
#     'unique_percent': 2.6385,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.3157,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'so2',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.7713,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0588]': 0.14511873350923482,
#     '(0.353, 0.412]': 0.06068601583113457,
#     '(0.471, 0.529]': 0.024626209322779244,
#     '(0.647, 0.706]': 0.048372911169744945,
#     '(0.176, 0.235]': 0.18909410729991205,
#     '(0.765, 0.824]': 0.012313104661389622,
#     '(0.0588, 0.118]': 0.06068601583113457,
#     '(0.294, 0.353]': 0.13808267370272648,
#     '(0.118, 0.176]': 0.06772207563764292,
#     '(0.235, 0.294]': 0.04221635883905013,
#     '(0.706, 0.765]': 0.007036059806508356,
#     '(0.588, 0.647]': 0.023746701846965697,
#     '(0.412, 0.471]': 0.09410729991204925,
#     '(0.529, 0.588]': 0.04573438874230431,
#     '(0.941, 1.0]': 0.014072119613016711,
#     '(0.824, 0.882]': 0.025505716798592787,
#     '(0.882, 0.941]': 0.0008795074758135445},
#    'right_distribution': {'(-0.001, 0.0588]': 0.0316622691292876,
#     '(0.294, 0.353]': 0.0853122251539138,
#     '(0.471, 0.529]': 0.05980650835532102,
#     '(0.118, 0.176]': 0.13896218117854,
#     '(0.706, 0.765]': 0.014951627088830254,
#     '(0.588, 0.647]': 0.03430079155672823,
#     '(0.0588, 0.118]': 0.1442392260334213,
#     '(0.412, 0.471]': 0.06772207563764292,
#     '(0.235, 0.294]': 0.1090589270008795,
#     '(0.176, 0.235]': 0.13808267370272648,
#     '(0.765, 0.824]': 0.02198768689533861,
#     '(0.529, 0.588]': 0.04925241864555849,
#     '(0.353, 0.412]': 0.06860158311345646,
#     '(0.647, 0.706]': 0.024626209322779244,
#     '(0.824, 0.882]': 0.010554089709762533,
#     '(0.882, 0.941]': 0.0008795074758135445},
#    'distribution_distance': 0.30124497038683434,
#    'distribution_stability': {'raw_score': 0.30124497038683434,
#     'grade': 'Moderate',
#     'score': 59}},
#   {'name': 'y_am_pef',
#    'left_field_features': {'name': 'y_am_pef',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 348,
#     'unique_percent': 30.6069,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.6913,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'y_am_pef',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.628,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.188, 0.25]': 0.10026385224274406,
#     '(0.5, 0.562]': 0.058927000879507474,
#     '(0.938, 1.0]': 0.02198768689533861,
#     '(0.438, 0.5]': 0.11609498680738786,
#     '(0.312, 0.375]': 0.13016710642040458,
#     '(0.25, 0.312]': 0.10729991204925242,
#     '(0.0625, 0.125]': 0.05013192612137203,
#     '(0.625, 0.688]': 0.04573438874230431,
#     '(-0.001, 0.0625]': 0.04133685136323659,
#     '(0.688, 0.75]': 0.04221635883905013,
#     '(0.812, 0.875]': 0.024626209322779244,
#     '(0.375, 0.438]': 0.08091468777484609,
#     '(0.562, 0.625]': 0.06508355321020229,
#     '(0.125, 0.188]': 0.05013192612137203,
#     '(0.875, 0.938]': 0.030782761653474055,
#     '(0.75, 0.812]': 0.03430079155672823},
#    'right_distribution': {'(0.188, 0.25]': 0.12576956904133685,
#     '(0.375, 0.438]': 0.0870712401055409,
#     '(0.875, 0.938]': 0.040457343887423045,
#     '(0.5, 0.562]': 0.04661389621811785,
#     '(0.25, 0.312]': 0.11961301671064203,
#     '(0.125, 0.188]': 0.09586631486367635,
#     '(0.625, 0.688]': 0.04309586631486367,
#     '(0.0625, 0.125]': 0.058927000879507474,
#     '(0.688, 0.75]': 0.05013192612137203,
#     '(0.812, 0.875]': 0.027264731750219876,
#     '(0.312, 0.375]': 0.09410729991204925,
#     '(0.438, 0.5]': 0.10642040457343888,
#     '(0.562, 0.625]': 0.06156552330694811,
#     '(0.75, 0.812]': 0.04309586631486367},
#    'distribution_distance': 0.2061580187983927,
#    'distribution_stability': {'raw_score': 0.2061580187983927,
#     'grade': 'Good',
#     'score': 71}},
#   {'name': 'humidiffin',
#    'left_field_features': {'name': 'humidiffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 604,
#     'unique_percent': 53.1223,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.861,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'humidiffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.5057,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.267, 0.333]': 0.06420404573438875,
#     '(0.733, 0.8]': 0.07211961301671065,
#     '(0.467, 0.533]': 0.1090589270008795,
#     '(0.333, 0.4]': 0.10026385224274406,
#     '(0.6, 0.667]': 0.09674582233948989,
#     '(0.667, 0.733]': 0.10290237467018469,
#     '(0.533, 0.6]': 0.11961301671064203,
#     '(0.133, 0.2]': 0.04925241864555849,
#     '(-0.001, 0.0667]': 0.022867194371152155,
#     '(0.4, 0.467]': 0.1090589270008795,
#     '(0.2, 0.267]': 0.044854881266490766,
#     '(0.867, 0.933]': 0.021108179419525065,
#     '(0.933, 1.0]': 0.0158311345646438,
#     '(0.8, 0.867]': 0.0395778364116095,
#     '(0.0667, 0.133]': 0.032541776605101144},
#    'right_distribution': {'(0.133, 0.2]': 0.05452946350043975,
#     '(0.733, 0.8]': 0.09498680738786279,
#     '(0.467, 0.533]': 0.10026385224274406,
#     '(0.4, 0.467]': 0.09058927000879508,
#     '(0.6, 0.667]': 0.11169744942832015,
#     '(0.533, 0.6]': 0.12576956904133685,
#     '(0.2, 0.267]': 0.07299912049252419,
#     '(0.867, 0.933]': 0.02198768689533861,
#     '(0.667, 0.733]': 0.10554089709762533,
#     '(0.333, 0.4]': 0.0853122251539138,
#     '(0.267, 0.333]': 0.07036059806508356,
#     '(0.8, 0.867]': 0.05013192612137203,
#     '(0.0667, 0.133]': 0.014951627088830254,
#     '(0.933, 1.0]': 0.0008795074758135445},
#    'distribution_distance': 0.15995017222130523,
#    'distribution_stability': {'raw_score': 0.15995017222130523,
#     'grade': 'Good',
#     'score': 78}},
#   {'name': 'tempdiffin',
#    'left_field_features': {'name': 'tempdiffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 618,
#     'unique_percent': 54.3536,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.861,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'tempdiffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.6025,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.133, 0.2]': 0.09234828496042216,
#     '(0.267, 0.333]': 0.10993843447669305,
#     '(0.667, 0.733]': 0.06860158311345646,
#     '(0.733, 0.8]': 0.0395778364116095,
#     '(0.333, 0.4]': 0.08003518029903255,
#     '(0.933, 1.0]': 0.024626209322779244,
#     '(0.867, 0.933]': 0.020228671943711522,
#     '(0.0667, 0.133]': 0.03781882145998241,
#     '(0.533, 0.6]': 0.1011433597185576,
#     '(0.6, 0.667]': 0.0773966578715919,
#     '(0.4, 0.467]': 0.09674582233948989,
#     '(0.467, 0.533]': 0.10554089709762533,
#     '(0.2, 0.267]': 0.09938434476693052,
#     '(0.8, 0.867]': 0.025505716798592787,
#     '(-0.001, 0.0667]': 0.021108179419525065},
#    'right_distribution': {'(0.0667, 0.133]': 0.05804749340369393,
#     '(0.2, 0.267]': 0.12137203166226913,
#     '(0.267, 0.333]': 0.09234828496042216,
#     '(0.6, 0.667]': 0.08443271767810026,
#     '(0.667, 0.733]': 0.07827616534740545,
#     '(0.333, 0.4]': 0.07651715039577836,
#     '(0.867, 0.933]': 0.016710642040457344,
#     '(0.8, 0.867]': 0.032541776605101144,
#     '(0.733, 0.8]': 0.051890941072999124,
#     '(0.533, 0.6]': 0.10378188214599825,
#     '(0.4, 0.467]': 0.07299912049252419,
#     '(0.133, 0.2]': 0.0932277924362357,
#     '(0.467, 0.533]': 0.11081794195250659,
#     '(-0.001, 0.0667]': 0.007036059806508356},
#    'distribution_distance': 0.14326118915122613,
#    'distribution_stability': {'raw_score': 0.14326118915122613,
#     'grade': 'Excellent',
#     'score': 80}},
#   {'name': 'no2',
#    'left_field_features': {'name': 'no2',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 363,
#     'unique_percent': 31.9261,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.7784,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'no2',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.7326,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.0588, 0.118]': 0.08970976253298153,
#     '(0.412, 0.471]': 0.0773966578715919,
#     '(0.176, 0.235]': 0.11785400175901495,
#     '(0.118, 0.176]': 0.14072119613016712,
#     '(0.706, 0.765]': 0.01759014951627089,
#     '(0.941, 1.0]': 0.014951627088830254,
#     '(0.235, 0.294]': 0.10993843447669305,
#     '(0.294, 0.353]': 0.08267370272647317,
#     '(0.765, 0.824]': 0.023746701846965697,
#     '(0.353, 0.412]': 0.08267370272647317,
#     '(0.824, 0.882]': 0.014951627088830254,
#     '(0.471, 0.529]': 0.06684256816182937,
#     '(-0.001, 0.0588]': 0.05013192612137203,
#     '(0.588, 0.647]': 0.024626209322779244,
#     '(0.529, 0.588]': 0.051890941072999124,
#     '(0.647, 0.706]': 0.027264731750219876,
#     '(0.882, 0.941]': 0.007036059806508356},
#    'right_distribution': {'(0.0588, 0.118]': 0.10729991204925242,
#     '(0.294, 0.353]': 0.09674582233948989,
#     '(0.176, 0.235]': 0.14951627088830255,
#     '(0.471, 0.529]': 0.05804749340369393,
#     '(0.647, 0.706]': 0.04397537379067722,
#     '(0.824, 0.882]': 0.01759014951627089,
#     '(0.118, 0.176]': 0.14511873350923482,
#     '(0.235, 0.294]': 0.13368513632365875,
#     '(0.765, 0.824]': 0.0158311345646438,
#     '(0.353, 0.412]': 0.05980650835532102,
#     '(0.706, 0.765]': 0.026385224274406333,
#     '(0.588, 0.647]': 0.03605980650835532,
#     '(0.529, 0.588]': 0.040457343887423045,
#     '(0.412, 0.471]': 0.051011433597185574,
#     '(-0.001, 0.0588]': 0.0158311345646438,
#     '(0.882, 0.941]': 0.002638522427440633},
#    'distribution_distance': 0.16031013821661366,
#    'distribution_stability': {'raw_score': 0.16031013821661366,
#     'grade': 'Good',
#     'score': 78}},
#   {'name': 'pm25diffin',
#    'left_field_features': {'name': 'pm25diffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 537,
#     'unique_percent': 47.2296,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8575,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'pm25diffin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.4318,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(0.75, 0.812]': 0.08795074758135445,
#     '(0.625, 0.688]': 0.148636763412489,
#     '(0.375, 0.438]': 0.07036059806508356,
#     '(0.5, 0.562]': 0.12401055408970976,
#     '(0.25, 0.312]': 0.036939313984168866,
#     '(0.688, 0.75]': 0.11785400175901495,
#     '(0.562, 0.625]': 0.14072119613016712,
#     '(-0.001, 0.0625]': 0.014951627088830254,
#     '(0.438, 0.5]': 0.1011433597185576,
#     '(0.812, 0.875]': 0.04573438874230431,
#     '(0.188, 0.25]': 0.020228671943711522,
#     '(0.312, 0.375]': 0.04133685136323659,
#     '(0.938, 1.0]': 0.014072119613016711,
#     '(0.0625, 0.125]': 0.0043975373790677225,
#     '(0.125, 0.188]': 0.011433597185576077,
#     '(0.875, 0.938]': 0.020228671943711522},
#    'right_distribution': {'(0.812, 0.875]': 0.03781882145998241,
#     '(0.625, 0.688]': 0.15567282321899736,
#     '(0.688, 0.75]': 0.14072119613016712,
#     '(0.438, 0.5]': 0.08267370272647317,
#     '(0.375, 0.438]': 0.07299912049252419,
#     '(0.25, 0.312]': 0.032541776605101144,
#     '(0.75, 0.812]': 0.09674582233948989,
#     '(0.562, 0.625]': 0.16710642040457344,
#     '(0.125, 0.188]': 0.011433597185576077,
#     '(0.5, 0.562]': 0.11785400175901495,
#     '(0.188, 0.25]': 0.022867194371152155,
#     '(0.312, 0.375]': 0.05013192612137203,
#     '(0.875, 0.938]': 0.0079155672823219,
#     '(0.0625, 0.125]': 0.003518029903254178},
#    'distribution_distance': 0.14069068005450197,
#    'distribution_stability': {'raw_score': 0.14069068005450197,
#     'grade': 'Excellent',
#     'score': 81}},
#   {'name': 'pm10',
#    'left_field_features': {'name': 'pm10',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 499,
#     'unique_percent': 43.8874,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8602,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'pm10',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.7045,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0588]': 0.04661389621811785,
#     '(0.294, 0.353]': 0.12137203166226913,
#     '(0.471, 0.529]': 0.06772207563764292,
#     '(0.353, 0.412]': 0.12049252418645559,
#     '(0.588, 0.647]': 0.040457343887423045,
#     '(0.824, 0.882]': 0.026385224274406333,
#     '(0.235, 0.294]': 0.13280562884784522,
#     '(0.176, 0.235]': 0.11433597185576078,
#     '(0.412, 0.471]': 0.09674582233948989,
#     '(0.118, 0.176]': 0.0633245382585752,
#     '(0.765, 0.824]': 0.014951627088830254,
#     '(0.941, 1.0]': 0.0158311345646438,
#     '(0.0588, 0.118]': 0.05980650835532102,
#     '(0.706, 0.765]': 0.008795074758135445,
#     '(0.882, 0.941]': 0.0158311345646438,
#     '(0.529, 0.588]': 0.0395778364116095,
#     '(0.647, 0.706]': 0.014951627088830254},
#    'right_distribution': {'(0.0588, 0.118]': 0.056288478452066845,
#     '(0.353, 0.412]': 0.12225153913808268,
#     '(0.529, 0.588]': 0.028144239226033423,
#     '(0.824, 0.882]': 0.01759014951627089,
#     '(0.235, 0.294]': 0.14072119613016712,
#     '(0.176, 0.235]': 0.13896218117854,
#     '(0.294, 0.353]': 0.12225153913808268,
#     '(0.118, 0.176]': 0.1345646437994723,
#     '(0.647, 0.706]': 0.022867194371152155,
#     '(0.412, 0.471]': 0.08091468777484609,
#     '(0.765, 0.824]': 0.0316622691292876,
#     '(0.706, 0.765]': 0.02198768689533861,
#     '(0.471, 0.529]': 0.051011433597185574,
#     '(0.588, 0.647]': 0.021108179419525065,
#     '(0.882, 0.941]': 0.007036059806508356,
#     '(-0.001, 0.0588]': 0.002638522427440633},
#    'distribution_distance': 0.216038723843852,
#    'distribution_stability': {'raw_score': 0.216038723843852,
#     'grade': 'Good',
#     'score': 70}},
#   {'name': 'pm25',
#    'left_field_features': {'name': 'pm25',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 481,
#     'unique_percent': 42.3043,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8707,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'pm25',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.8382,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0556]': 0.0853122251539138,
#     '(0.222, 0.278]': 0.10466138962181179,
#     '(0.5, 0.556]': 0.022867194371152155,
#     '(0.444, 0.5]': 0.026385224274406333,
#     '(0.722, 0.778]': 0.0158311345646438,
#     '(0.278, 0.333]': 0.1248900615655233,
#     '(0.111, 0.167]': 0.1521547933157432,
#     '(0.0556, 0.111]': 0.13720316622691292,
#     '(0.611, 0.667]': 0.018469656992084433,
#     '(0.333, 0.389]': 0.06508355321020229,
#     '(0.556, 0.611]': 0.021108179419525065,
#     '(0.389, 0.444]': 0.051011433597185574,
#     '(0.667, 0.722]': 0.014951627088830254,
#     '(0.833, 0.889]': 0.010554089709762533,
#     '(0.167, 0.222]': 0.12313104661389622,
#     '(0.778, 0.833]': 0.008795074758135445,
#     '(0.889, 0.944]': 0.005277044854881266,
#     '(0.944, 1.0]': 0.012313104661389622},
#    'right_distribution': {'(0.0556, 0.111]': 0.17941952506596306,
#     '(0.222, 0.278]': 0.12928759894459102,
#     '(0.444, 0.5]': 0.027264731750219876,
#     '(0.778, 0.833]': 0.021108179419525065,
#     '(0.111, 0.167]': 0.20932277924362358,
#     '(0.167, 0.222]': 0.1503957783641161,
#     '(0.722, 0.778]': 0.0158311345646438,
#     '(0.333, 0.389]': 0.06772207563764292,
#     '(0.667, 0.722]': 0.019349164467897976,
#     '(0.278, 0.333]': 0.07563764291996482,
#     '(0.389, 0.444]': 0.032541776605101144,
#     '(0.833, 0.889]': 0.007036059806508356,
#     '(0.611, 0.667]': 0.014072119613016711,
#     '(0.889, 0.944]': 0.014951627088830254,
#     '(0.5, 0.556]': 0.02198768689533861,
#     '(0.556, 0.611]': 0.009674582233948988,
#     '(-0.001, 0.0556]': 0.0043975373790677225},
#    'distribution_distance': 0.23952423620595537,
#    'distribution_stability': {'raw_score': 0.23952423620595537,
#     'grade': 'Good',
#     'score': 67}},
#   {'name': 'income',
#    'left_field_features': {'name': 'income',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 8,
#     'unique_percent': 0.7036,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.4934,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'income',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.4653,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.812, 0.875]': 0.06948109058927,
#     '(0.688, 0.75]': 0.27616534740545295,
#     '(0.562, 0.625]': 0.17941952506596306,
#     '(0.125, 0.188]': 0.07651715039577836,
#     '(0.25, 0.312]': 0.052770448548812667,
#     '(0.375, 0.438]': 0.09234828496042216,
#     '(0.938, 1.0]': 0.20316622691292877,
#     '(-0.001, 0.0625]': 0.05013192612137203},
#    'right_distribution': {'(0.75, 0.812]': 0.14160070360598065,
#     '(0.812, 0.875]': 0.051011433597185574,
#     '(0.562, 0.625]': 0.08795074758135445,
#     '(0.125, 0.188]': 0.032541776605101144,
#     '(0.188, 0.25]': 0.019349164467897976,
#     '(0.438, 0.5]': 0.036939313984168866,
#     '(0.5, 0.562]': 0.06684256816182937,
#     '(0.875, 0.938]': 0.08267370272647317,
#     '(0.938, 1.0]': 0.13808267370272648,
#     '(0.688, 0.75]': 0.10729991204925242,
#     '(0.0625, 0.125]': 0.06508355321020229,
#     '(0.625, 0.688]': 0.07299912049252419,
#     '(0.312, 0.375]': 0.029023746701846966,
#     '(0.25, 0.312]': 0.022867194371152155,
#     '(-0.001, 0.0625]': 0.018469656992084433,
#     '(0.375, 0.438]': 0.027264731750219876},
#    'distribution_distance': 0.5761921113658411,
#    'distribution_stability': {'raw_score': 0.5761921113658411,
#     'grade': 'Poor',
#     'score': 31}},
#   {'name': 'airp',
#    'left_field_features': {'name': 'airp',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 531,
#     'unique_percent': 46.7018,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8681,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'airp',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.511,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0667]': 0.025505716798592787,
#     '(0.4, 0.467]': 0.11521547933157432,
#     '(0.333, 0.4]': 0.06860158311345646,
#     '(0.867, 0.933]': 0.06860158311345646,
#     '(0.533, 0.6]': 0.1266490765171504,
#     '(0.6, 0.667]': 0.09762532981530343,
#     '(0.8, 0.867]': 0.051890941072999124,
#     '(0.933, 1.0]': 0.016710642040457344,
#     '(0.267, 0.333]': 0.04397537379067722,
#     '(0.733, 0.8]': 0.07563764291996482,
#     '(0.667, 0.733]': 0.11345646437994723,
#     '(0.133, 0.2]': 0.03430079155672823,
#     '(0.467, 0.533]': 0.11169744942832015,
#     '(0.2, 0.267]': 0.036939313984168866,
#     '(0.0667, 0.133]': 0.013192612137203167},
#    'right_distribution': {'(0.0667, 0.133]': 0.014072119613016711,
#     '(0.4, 0.467]': 0.12313104661389622,
#     '(0.333, 0.4]': 0.07036059806508356,
#     '(0.467, 0.533]': 0.09498680738786279,
#     '(0.8, 0.867]': 0.08443271767810026,
#     '(0.533, 0.6]': 0.11521547933157432,
#     '(0.6, 0.667]': 0.09498680738786279,
#     '(0.733, 0.8]': 0.12137203166226913,
#     '(0.867, 0.933]': 0.026385224274406333,
#     '(0.2, 0.267]': 0.051011433597185574,
#     '(0.667, 0.733]': 0.11169744942832015,
#     '(0.267, 0.333]': 0.05804749340369393,
#     '(0.133, 0.2]': 0.03430079155672823},
#    'distribution_distance': 0.19272551291479142,
#    'distribution_stability': {'raw_score': 0.19272551291479142,
#     'grade': 'Good',
#     'score': 73}},
#   {'name': 'pm25in',
#    'left_field_features': {'name': 'pm25in',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 563,
#     'unique_percent': 49.5163,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8461,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'pm25in',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 7,
#     'max_str_length': 11,
#     'avg_str_length': 9.737,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 5,
#     'max_precision': 9},
#    'left_distribution': {'(0.235, 0.294]': 0.1266490765171504,
#     '(0.353, 0.412]': 0.079155672823219,
#     '(-0.001, 0.0588]': 0.08355321020228672,
#     '(0.471, 0.529]': 0.05804749340369393,
#     '(0.118, 0.176]': 0.10993843447669305,
#     '(0.588, 0.647]': 0.036939313984168866,
#     '(0.529, 0.588]': 0.03430079155672823,
#     '(0.176, 0.235]': 0.11169744942832015,
#     '(0.412, 0.471]': 0.08003518029903255,
#     '(0.0588, 0.118]': 0.1011433597185576,
#     '(0.294, 0.353]': 0.1090589270008795,
#     '(0.647, 0.706]': 0.024626209322779244,
#     '(0.765, 0.824]': 0.008795074758135445,
#     '(0.941, 1.0]': 0.011433597185576077,
#     '(0.706, 0.765]': 0.010554089709762533,
#     '(0.882, 0.941]': 0.0079155672823219,
#     '(0.824, 0.882]': 0.006156552330694811},
#    'right_distribution': {'(0.176, 0.235]': 0.13896218117854,
#     '(0.235, 0.294]': 0.12049252418645559,
#     '(0.118, 0.176]': 0.1741424802110818,
#     '(0.412, 0.471]': 0.06948109058927,
#     '(0.353, 0.412]': 0.09498680738786279,
#     '(0.706, 0.765]': 0.01759014951627089,
#     '(0.647, 0.706]': 0.02990325417766051,
#     '(0.0588, 0.118]': 0.09938434476693052,
#     '(0.294, 0.353]': 0.10642040457343888,
#     '(0.588, 0.647]': 0.032541776605101144,
#     '(0.824, 0.882]': 0.010554089709762533,
#     '(0.471, 0.529]': 0.04133685136323659,
#     '(-0.001, 0.0588]': 0.014072119613016711,
#     '(0.882, 0.941]': 0.006156552330694811,
#     '(0.529, 0.588]': 0.028144239226033423,
#     '(0.765, 0.824]': 0.014951627088830254,
#     '(0.941, 1.0]': 0.0008795074758135445},
#    'distribution_distance': 0.1846633343448516,
#    'distribution_stability': {'raw_score': 0.1846633343448516,
#     'grade': 'Good',
#     'score': 74}},
#   {'name': 'tempin',
#    'left_field_features': {'name': 'tempin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 607,
#     'unique_percent': 53.3861,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8584,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'tempin',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 10,
#     'avg_str_length': 9.5057,
#     'min_value': 0.1,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 8},
#    'left_distribution': {'(0.929, 1.0]': 0.027264731750219876,
#     '(0.714, 0.786]': 0.06508355321020229,
#     '(0.429, 0.5]': 0.11961301671064203,
#     '(0.357, 0.429]': 0.11521547933157432,
#     '(0.571, 0.643]': 0.10729991204925242,
#     '(0.0714, 0.143]': 0.021108179419525065,
#     '(0.143, 0.214]': 0.04925241864555849,
#     '(0.5, 0.571]': 0.11257695690413369,
#     '(0.214, 0.286]': 0.06948109058927,
#     '(0.643, 0.714]': 0.07827616534740545,
#     '(0.786, 0.857]': 0.05804749340369393,
#     '(0.286, 0.357]': 0.11609498680738786,
#     '(0.857, 0.929]': 0.04397537379067722,
#     '(-0.001, 0.0714]': 0.016710642040457344},
#    'right_distribution': {'(0.714, 0.786]': 0.08795074758135445,
#     '(0.571, 0.643]': 0.15567282321899736,
#     '(0.643, 0.714]': 0.1169744942832014,
#     '(0.286, 0.357]': 0.13720316622691292,
#     '(0.214, 0.286]': 0.0853122251539138,
#     '(0.143, 0.214]': 0.019349164467897976,
#     '(0.357, 0.429]': 0.11345646437994723,
#     '(0.429, 0.5]': 0.1266490765171504,
#     '(0.5, 0.571]': 0.12752858399296393,
#     '(0.786, 0.857]': 0.027264731750219876,
#     '(0.857, 0.929]': 0.002638522427440633},
#    'distribution_distance': 0.25763995877502194,
#    'distribution_stability': {'raw_score': 0.25763995877502194,
#     'grade': 'Good',
#     'score': 65}},
#   {'name': 'co',
#    'left_field_features': {'name': 'co',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 449,
#     'unique_percent': 39.4899,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 3,
#     'max_str_length': 5,
#     'avg_str_length': 4.8637,
#     'min_value': 1,
#     'max_value': 1.0,
#     'min_precision': 0,
#     'max_precision': 3},
#    'right_field_features': {'name': 'co',
#     'type': 'numeric',
#     'count': 1137,
#     'unique_count': 1136,
#     'unique_percent': 99.912,
#     'missing_count': 0,
#     'missing_percent': 0.0,
#     'min_str_length': 6,
#     'max_str_length': 11,
#     'avg_str_length': 9.7318,
#     'min_value': 0.01,
#     'max_value': 0.1,
#     'min_precision': 4,
#     'max_precision': 9},
#    'left_distribution': {'(-0.001, 0.0588]': 0.056288478452066845,
#     '(0.235, 0.294]': 0.12313104661389622,
#     '(0.0588, 0.118]': 0.11257695690413369,
#     '(0.294, 0.353]': 0.1248900615655233,
#     '(0.882, 0.941]': 0.0079155672823219,
#     '(0.824, 0.882]': 0.014951627088830254,
#     '(0.176, 0.235]': 0.1090589270008795,
#     '(0.118, 0.176]': 0.13984168865435356,
#     '(0.471, 0.529]': 0.029023746701846966,
#     '(0.412, 0.471]': 0.06068601583113457,
#     '(0.353, 0.412]': 0.08003518029903255,
#     '(0.765, 0.824]': 0.014072119613016711,
#     '(0.529, 0.588]': 0.0316622691292876,
#     '(0.941, 1.0]': 0.013192612137203167,
#     '(0.706, 0.765]': 0.020228671943711522,
# ...
#    '391': -1.5095191749,
#    '392': -0.7533859389,
#    '393': 3.5658644844,
#    '394': -0.3834887929,
#    '395': -0.2227532879,
#    '396': 5.8881854621,
#    '397': 1.1714389438,
#    '398': 0.270737916,
#    '399': -2.4033859569,
#    '400': 1.0742734938,
#    '401': 3.6698776941,
#    '402': -1.215917837,
#    '403': -1.5409194756,
#    '404': -0.8268693193,
#    '405': 0.653473256,
#    '406': -1.187477046,
#    '407': -2.6247078501,
#    '408': 4.2496210214,
#    '409': -0.4795155897,
#    '410': 5.0790752205,
#    '411': 6.6447428794,
#    '412': -1.4906526865,
#    '413': 5.4454059144,
#    '414': -0.8823399814,
#    '415': -2.3976936459,
#    '416': -2.8314513997,
#    '417': 6.1010959623,
#    '418': 1.4455515205,
#    '419': -0.1751414441,
#    '420': 1.7025605205,
#    '421': -1.909630814,
#    '422': 0.8098123765,
#    '423': -2.9474802086,
#    '424': 2.6130804654,
#    '425': 3.3997857821,
#    '426': 0.2221695115,
#    '427': -0.7741255383,
#    '428': -2.422097557,
#    '429': -1.9319645941,
#    '430': -1.0296074884,
#    '431': -1.8513659635,
#    '432': -1.785490505,
#    '433': -1.2251751463,
#    '434': 4.5222640628,
#    '435': -1.1801647321,
#    '436': -1.3919101318,
#    '437': -1.7949177976,
#    '438': 0.9977516791,
#    '439': 1.422465774,
#    '440': 0.4278831629,
#    '441': -1.9317345446,
#    '442': -0.6683772136,
#    '443': -0.1990106545,
#    '444': 7.368326336,
#    '445': 0.7945216888,
#    '446': 0.6208403092,
#    '447': 5.0791195358,
#    '448': -2.0236867248,
#    '449': -3.8082045144,
#    '450': 5.3343421234,
#    '451': -1.7917230745,
#    '452': -0.4527589041,
#    '453': -0.585421639,
#    '454': -2.614089,
#    '455': -0.3141081588,
#    '456': 0.5058075493,
#    '457': -0.3008925955,
#    '458': 0.9099690969,
#    '459': -0.9354064867,
#    '460': 5.8693653475,
#    '461': -1.3332241144,
#    '462': -1.4268842464,
#    '463': -0.3376718736,
#    '464': -0.5958439553,
#    '465': 0.0668713032,
#    '466': 1.9516965535,
#    '467': 4.5489077185,
#    '468': 1.9394269678,
#    '469': -2.1091868475,
#    '470': -0.4160598564,
#    '471': 0.3396075227,
#    '472': 0.6081057772,
#    '473': 2.0078409499,
#    '474': 2.5844418224,
#    '475': 1.089598132,
#    '476': 3.7987023955,
#    '477': 5.7681111258,
#    '478': -1.3066410719,
#    '479': -0.0923692618,
#    '480': 0.1273944866,
#    '481': 5.6242058605,
#    '482': 0.1567135411,
#    '483': -0.746237534,
#    '484': 0.00949721,
#    '485': -0.0789237489,
#    '486': -1.1887224587,
#    '487': -3.9751958924,
#    '488': -0.0854540307,
#    '489': 0.1810153778,
#    '490': -0.4369580116,
#    '491': 3.1071689059,
#    '492': 2.3965351477,
#    '493': -1.7024140511,
#    '494': -1.2499855674,
#    '495': -0.4264784008,
#    '496': -2.5737284725,
#    '497': -3.0971671404,
#    '498': 3.6164062319,
#    '499': 2.4886024255,
#    '500': 2.8193567774,
#    '501': 1.0988612951,
#    '502': -0.3613813691,
#    '503': -2.500663897,
#    '504': 0.281143265,
#    '505': 2.0816163945,
#    '506': -1.3957606866,
#    '507': -1.0848146294,
#    '508': -0.7908928117,
#    '509': -2.7289446439,
#    '510': -1.7511838983,
#    '511': 1.3692277057,
#    '512': 0.622615487,
#    '513': 1.5892740712,
#    '514': -1.4293750236,
#    '515': -0.2468818621,
#    '516': -1.8276110507,
#    '517': 0.4339350624,
#    '518': 1.6568633751,
#    '519': -2.4900633338,
#    '520': 0.3415733587,
#    '521': 3.6870084518,
#    '522': -2.5906556594,
#    '523': -3.8143399073,
#    '524': -0.490148948,
#    '525': 0.1700557905,
#    '526': -0.396770155,
#    '527': -3.3852664243,
#    '528': -3.4403256068,
#    '529': -0.8071342448,
#    '530': -1.3785853967,
#    '531': -1.7234978709,
#    '532': -1.4148190893,
#    '533': -2.1239957157,
#    '534': 5.8411535011,
#    '535': 0.8450126042,
#    '536': -3.8136989283,
#    '537': 1.7181085363,
#    '538': 1.6814403753,
#    '539': 1.7915299713,
#    '540': 5.3001254259,
#    '541': -0.6290060102,
#    '542': 0.502258032,
#    '543': 1.2254250987,
#    '544': -0.1661442466,
#    '545': 1.2257943034,
#    '546': -3.4670671505,
#    '547': -1.5976785617,
#    '548': 2.3715187688,
#    '549': -0.2747595945,
#    '550': -2.2024756158,
#    '551': -1.9646533342,
#    '552': -0.7265040976,
#    '553': -3.4115083916,
#    '554': 6.2207252234,
#    '555': 1.0890172902,
#    '556': 0.6773387506,
#    '557': -2.3457755393,
#    '558': 4.2030092943,
#    '559': 4.7213516618,
#    '560': 5.4838634785,
#    '561': -1.3495019654,
#    '562': 3.4544069953,
#    '563': 0.2605313422,
#    '564': 3.0277992343,
#    '565': -3.5518139935,
#    '566': -1.070264301,
#    '567': 5.59818605,
#    '568': -2.2949108915,
#    '569': -1.8593808228,
#    '570': 1.034181809,
#    '571': 0.2547578751,
#    '572': -2.4797085553,
#    '573': -1.9189056484,
#    '574': -1.617103907,
#    '575': 3.0355844164,
#    '576': -1.2999322387,
#    '577': -1.5152438157,
#    '578': -2.5650858331,
#    '579': 4.2012919856,
#    '580': -1.1500787795,
#    '581': -2.8048932223,
#    '582': 6.3206708766,
#    '583': -2.6711623219,
#    '584': -1.309778968,
#    '585': -2.5116383178,
#    '586': -2.1882526835,
#    '587': -1.1459904601,
#    '588': 3.7246774595,
#    '589': 3.2576498906,
#    '590': 0.828724728,
#    '591': 1.3872429847,
#    '592': -1.1058508359,
#    '593': -0.29829454,
#    '594': -2.8819532939,
#    '595': 2.5874995616,
#    '596': -0.1341947293,
#    '597': -0.178915524,
#    '598': -1.0601510967,
#    '599': 0.7442788338,
#    '600': 2.1671085196,
#    '601': -2.0254458886,
#    '602': 1.1919516045,
#    '603': 0.1322993119,
#    '604': -1.7886098345,
#    '605': -0.8759717057,
#    '606': -2.1981634682,
#    '607': -2.161894614,
#    '608': -1.5422912803,
#    '609': -0.3167428484,
#    '610': -1.9336275574,
#    '611': 2.9221269626,
#    '612': -1.6160744526,
#    '613': -1.0173750449,
#    '614': 4.2273828587,
#    '615': 1.4158608767,
#    '616': -3.5836457664,
#    '617': 0.0080711926,
#    '618': 0.4101227137,
#    '619': -2.0836715431,
#    '620': -3.550009288,
#    '621': -0.8004950825,
#    '622': -2.1733553792,
#    '623': -2.0683838543,
#    '624': 0.6774557348,
#    '625': 1.9559593166,
#    '626': 1.7144751647,
#    '627': -2.1832540826,
#    '628': 0.4566158763,
#    '629': -1.5248130195,
#    '630': -0.7081312495,
#    '631': 6.437977234,
#    '632': 2.0936057947,
#    '633': 4.5603661371,
#    '634': -2.1177638266,
#    '635': 5.8353450028,
#    '636': 2.5329621011,
#    '637': -1.0432170559,
#    '638': -1.8771660439,
#    '639': -3.6929552777,
#    '640': 1.7493287993,
#    '641': 3.6718440235,
#    '642': 5.3169951584,
#    '643': -0.8044715163,
#    '644': -1.1283713914,
#    '645': -1.4768639375,
#    '646': -1.3858831665,
#    '647': -0.8694919637,
#    '648': -1.9730995982,
#    '649': -3.3521726567,
#    '650': 3.4140197027,
#    '651': -0.1244431534,
#    '652': -0.2336457005,
#    '653': 0.2018496079,
#    '654': 0.7476727072,
#    '655': 0.2829664412,
#    '656': 0.1289186269,
#    '657': 3.4308841825,
#    '658': -1.6860726077,
#    '659': -0.6141914115,
#    '660': 1.5111575056,
#    '661': -0.9118002411,
#    '662': 0.5438639849,
#    '663': -0.0117735257,
#    '664': -1.2995877542,
#    '665': -1.8115197568,
#    '666': -1.5974509087,
#    '667': 0.0343009118,
#    '668': -1.9500304444,
#    '669': -1.5350680264,
#    '670': 2.5608286658,
#    '671': 0.5807319163,
#    '672': -1.7387417108,
#    '673': 0.0551290466,
#    '674': -1.1214145708,
#    '675': 1.3397257636,
#    '676': -3.1422595816,
#    '677': -2.35227396,
#    '678': -0.2781708277,
#    '679': 1.6229756336,
#    '680': -2.7827137905,
#    '681': -2.612035666,
#    '682': 1.2368953006,
#    '683': -1.6746165158,
#    '684': -0.1612657443,
#    '685': -0.8264058469,
#    '686': -1.8492968167,
#    '687': -2.0698231717,
#    '688': 1.5519215872,
#    '689': -2.0467277819,
#    '690': -0.8540842493,
#    '691': -2.2092982071,
#    '692': 1.2973504023,
#    '693': -1.1872437707,
#    '694': -1.2253683222,
#    '695': -2.1053207341,
#    '696': -0.0746400508,
#    '697': -1.8639998814,
#    '698': -2.1280458282,
#    '699': 3.2196312429,
#    '700': -1.9624069011,
#    '701': -2.6831164721,
#    '702': 0.0759990809,
#    '703': 1.8199483436,
#    '704': -1.4963562678,
#    '705': 1.713715156,
#    '706': 1.6056107777,
#    '707': -2.0747270087,
#    '708': 0.0227631638,
#    '709': 0.3475139483,
#    '710': -1.7270115794,
#    '711': -0.7160178939,
#    '712': -2.1788885921,
#    '713': 0.5864132559,
#    '714': -0.7581420038,
#    '715': 2.3645636266,
#    '716': -3.6321468672,
#    '717': -1.2614196995,
#    '718': -2.9304339821,
#    '719': -3.2889619286,
#    '720': -2.1650645479,
#    '721': -1.0802023885,
#    '722': -2.4351751788,
#    '723': -0.0224728676,
#    '724': -2.1118884395,
#    '725': -0.0297476333,
#    '726': -0.2920174687,
#    '727': 0.6675450556,
#    '728': 1.4464949939,
#    '729': 7.1410520777,
#    '730': 0.270008283,
#    '731': -1.7378606575,
#    '732': -0.8508672704,
#    '733': -1.2170373189,
#    '734': 6.4660361405,
#    '735': -0.956924161,
#    '736': -2.1018280475,
#    '737': 2.7948026372,
#    '738': 0.5122386331,
#    '739': 0.3434201284,
#    '740': 0.5743941411,
#    '741': -0.5474631795,
#    '742': 3.6121954619,
#    '743': 4.2338349462,
#    '744': -1.9545382851,
#    '745': 3.4365065794,
#    '746': 0.0330799762,
#    '747': 1.9723946087,
#    '748': -3.2895404012,
#    '749': 1.3098350928,
#    '750': -0.632037337,
#    '751': 2.0934169015,
#    '752': -1.3602923114,
#    '753': -1.578713283,
#    '754': 0.4250448632,
#    '755': -2.3834347401,
#    '756': -3.2699319192,
#    '757': 1.9073033645,
#    '758': -1.4888928258,
#    '759': 2.130889431,
#    '760': 4.1708777521,
#    '761': 1.182442972,
#    '762': -2.4689810639,
#    '763': -0.0449926449,
#    '764': -1.3472986545,
#    '765': -3.2264955359,
#    '766': 0.4274761427,
#    '767': -0.7497996409,
#    '768': 1.0443443985,
#    '769': -2.9762331922,
#    '770': -0.9083606851,
#    '771': -0.7748938233,
#    '772': -2.29739301,
#    '773': -0.9620943669,
#    '774': -1.7434751745,
#    '775': 1.2523748324,
#    '776': 1.1006060752,
#    '777': 0.3974248927,
#    '778': -1.4658172198,
#    '779': 1.2166556488,
#    '780': 4.9344913025,
#    '781': 5.5532502997,
#    '782': 1.0457984918,
#    '783': 2.0543426689,
#    '784': -1.4685743425,
#    '785': -2.0347701116,
#    '786': -0.8682376222,
#    '787': 0.806997714,
#    '788': -1.2553855148,
#    '789': -2.2341418269,
#    '790': -2.6191025029,
#    '791': -1.961549239,
#    '792': 3.7736731763,
#    '793': 5.3340934644,
#    '794': 0.5321544372,
#    '795': -2.7238793693,
#    '796': 2.8543884613,
#    '797': 2.5884162432,
#    '798': -0.4930754595,
#    '799': 0.634925608,
#    '800': -0.8899991621,
#    '801': -1.5993850513,
#    '802': 0.0307759181,
#    '803': -1.4012617823,
#    '804': 0.6177534975,
#    '805': 6.3221623672,
#    '806': -1.8753033177,
#    '807': -1.1762812057,
#    '808': 3.5868384683,
#    '809': -0.9636089876,
#    '810': -3.2174525007,
#    '811': 0.1517539658,
#    '812': -2.6859316561,
#    '813': 1.216944924,
#    '814': -2.5374595439,
#    '815': 4.4441462784,
#    '816': -2.8174555336,
#    '817': -2.3762845702,
#    '818': -1.0598405036,
#    '819': 1.0937911819,
#    '820': 0.0264086947,
#    '821': 6.4135166936,
#    '822': 1.4440676667,
#    '823': 2.4534576419,
#    '824': -1.8892673614,
#    '825': 1.4478348818,
#    '826': 1.3367878216,
#    '827': -0.6836134978,
#    '828': 4.782938133,
#    '829': 0.1576698046,
#    '830': 5.4458409754,
#    '831': -2.2375532027,
#    '832': -3.2004098361,
#    '833': 0.0223688341,
#    '834': 0.388427329,
#    '835': -3.2472214907,
#    '836': -0.814415281,
#    '837': 1.8304260924,
#    '838': 0.9951646108,
#    '839': 1.3776525679,
#    '840': 1.4889896523,
#    '841': 3.1445861397,
#    '842': -0.8795432931,
#    '843': -1.0728074136,
#    '844': -1.0856630405,
#    '845': -1.7114615768,
#    '846': 0.1971793885,
#    '847': 1.773298103,
#    '848': -3.08677324,
#    '849': 0.330598344,
#    '850': -1.0925720952,
#    '851': -1.0896844385,
#    '852': 0.1356550963,
#    '853': -2.4357752765,
#    '854': -3.1433271847,
#    '855': 2.1629773363,
#    '856': -0.9302933313,
#    '857': -2.3201898871,
#    '858': -1.0427573389,
#    '859': -1.0723045761,
#    '860': -0.5724668614,
#    '861': 4.1344897444,
#    '862': 1.9136715318,
#    '863': 0.896277582,
#    '864': 4.790483817,
#    '865': -0.5684445861,
#    '866': 3.5221757747,
#    '867': 3.5352479523,
#    '868': 4.6798048192,
#    '869': 2.2733566167,
#    '870': -2.6061893158,
#    '871': -2.1093810635,
#    '872': 0.1676513678,
#    '873': 4.6452029686,
#    '874': -1.8491186896,
#    '875': 6.3714673586,
#    '876': -0.3537278952,
#    '877': -2.1156287133,
#    '878': 1.5097938893,
#    '879': -2.1237908323,
#    '880': -1.6127228235,
#    '881': -1.7619526527,
#    '882': 3.9477896532,
#    '883': -0.1279205245,
#    '884': -2.8715756117,
#    '885': -1.6203292072,
#    '886': -1.9683004114,
#    '887': -1.9460439692,
#    '888': -0.0292785836,
#    '889': -0.1899051822,
#    '890': -1.3899746191,
#    '891': -0.2081161156,
#    '892': 0.5940050809,
#    '893': -1.7561852507,
#    '894': 1.369963154,
#    '895': 0.0763470978,
#    '896': 3.5377932079,
#    '897': -2.7492555888,
#    '898': -0.1682749498,
#    '899': -3.206867181,
#    '900': 0.7221308865,
#    '901': -2.1010956993,
#    '902': 6.7909811189,
#    '903': -0.4395480686,
#    '904': 3.1285886802,
#    '905': -2.0507416541,
#    '906': -0.8477964338,
#    '907': 0.0169086784,
#    '908': -3.0903552749,
#    '909': -3.7256342827,
#    '910': -3.1095770791,
#    '911': 1.2732372649,
#    '912': 1.4333460989,
#    '913': 5.6862281034,
#    '914': -3.3405778571,
#    '915': -0.6022761094,
#    '916': 1.6331490257,
#    '917': -1.0479455351,
#    '918': 0.4903281895,
#    '919': -1.8529757149,
#    '920': -1.6410465457,
#    '921': 2.340410079,
#    '922': 6.1919934098,
#    '923': -0.38559531,
#    '924': -0.3070658314,
#    '925': -0.0679281098,
#    '926': 5.9832636234,
#    '927': 2.2532258246,
#    '928': 0.3947143129,
#    '929': -2.2841909266,
#    '930': -1.5639312053,
#    '931': 5.7839534162,
#    '932': -2.6723714374,
#    '933': 4.8198161537,
#    '934': -1.7832068092,
#    '935': -1.9835608064,
#    '936': -0.7451881737,
#    '937': -2.4535107304,
#    '938': -0.1996337919,
#    '939': -1.6398393256,
#    '940': 1.1491742811,
#    '941': 3.5835299451,
#    '942': -0.0977738304,
#    '943': 2.0747551769,
#    '944': -1.2387234678,
#    '945': 2.3130049815,
#    '946': -0.0761246207,
#    '947': -1.5136970188,
#    '948': 1.5785285541,
#    '949': -0.2856598009,
#    '950': -0.6770513712,
#    '951': 0.0223314491,
#    '952': 2.7230106114,
#    '953': -1.946553718,
#    '954': 0.4223403641,
#    '955': 0.6448924176,
#    '956': 1.4972221145,
#    '957': -1.6854364888,
#    '958': -3.318586456,
#    '959': 1.449036015,
#    '960': 4.9236736365,
#    '961': 3.96680576,
#    '962': 0.7137778907,
#    '963': -3.3201778008,
#    '964': -1.8010203737,
#    '965': -2.9576317787,
#    '966': -1.4094839594,
#    '967': -2.2367281912,
#    '968': -0.9638907193,
#    '969': -0.1791338606,
#    '970': -1.7626330127,
#    '971': -1.1872834567,
#    '972': 5.2526853261,
#    '973': 1.5263406729,
#    '974': -2.2380347593,
#    '975': -1.1994179169,
#    '976': -1.8695278021,
#    '977': -0.897209515,
#    '978': -2.2767704767,
#    '979': 3.7442722186,
#    '980': -1.7121936614,
#    '981': -1.1079276638,
#    '982': 2.5849832847,
#    '983': -0.9389576723,
#    '984': -2.1290999102,
#    '985': -1.9942380767,
#    '986': -2.0377799614,
#    '987': 1.3549190331,
#    '988': -0.5511255488,
#    '989': 2.5953748536,
#    '990': -0.6759158367,
#    '991': 0.3660385698,
#    '992': -1.1066431791,
#    '993': 0.1246458418,
#    '994': 0.7810202784,
#    '995': -3.2091364049,
#    '996': -1.6866441423,
#    '997': -0.4002243075,
#    '998': -0.1854992967,
#    '999': 3.2029155652,
#    ...}},
#  'synthetic_data_quality_score': {'raw_score': 83.82962962962962,
#   'grade': 'Excellent',
#   'score': 83},
#  'field_correlation_stability': {'raw_score': 0.052098343745878586,
#   'grade': 'Excellent',
#   'score': 83},
#  'principal_component_stability': {'raw_score': 0.08003834377226973,
#   'grade': 'Excellent',
#   'score': 100},
#  'field_distribution_stability': {'raw_score': 0.2252208018119478,
#   'grade': 'Good',
#   'score': 69},
#  'privacy_protection_level': {'grade': 'Normal',
#   'raw_score': 0,
#   'score': 0,
#   'outlier_filter': 'Disabled',
#   'similarity_filter': 'Disabled',
#   'overfitting_protection': 'Disabled',
#   'differential_privacy': 'Disabled'},
#  'model_id': '64be6680403c977eca4fbbf6',
#  'project_name': '',
#  'model_name': 'Evaluate Model',
#  'model_type': 'evaluate',
#  'fatal_error': False,
#  'summary': [{'field': 'synthetic_data_quality_score', 'value': 83},
#   {'field': 'field_correlation_stability', 'value': 83},
#   {'field': 'principal_component_stability', 'value': 100},
#   {'field': 'field_distribution_stability', 'value': 69},
#   {'field': 'privacy_protection_level', 'value': 0}]}

# %%
#Save Gretel Report as HTML 
#gretel models create --config evaluate/default --in-data L27_E22_20_B16_D20_22_Synthetic_minority_data.csv --ref-data L27_E22_20_B16_D20_22_Original_minority_data.csv --output report-dir
