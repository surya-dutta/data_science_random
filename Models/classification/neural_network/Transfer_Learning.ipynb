# %% [markdown]
# # TLSI DL3_V2
# transfer learning on aggregated, labeled dataset

# %%
import os
import sys
import importlib
import pickle
import keras
import pdb
import pandas as pd
from datetime import date, datetime

# %%
execution_path = "../../"
import os
os.path.abspath(os.getcwd())
# Out:
# 'c:\\Users\\41222\\OneDrive\\Documents\\Study-SU-Jay\\SU-2023-Research-TL\\Research-Project\\Models\\classification\\neural_network'

# %%
#GLOBALS AND FILEPATHS#
source_quantile = "0.2"

source_file_path = f"{execution_path}Input_Data/Og_Data/labeled_normal_data/all_pids_q={source_quantile}.npy"

display(source_file_path)
# Out:
# '../../Input_Data/Og_Data/labeled_normal_data/all_pids_q=0.2.npy'

# %%
from TL_Packages import *

# Architecture_GROUP = "TL"
Architecture_GROUP = "TL3_2f_28_32f_20f_20_1"

def runtime():
    print("Runtime:", datetime.now().hour, "o' clock and", datetime.now().minute, "minutes")

def run_tlsi(file):
    """
        run transfer learning algorithm on sample imbalanced data set
    """
    pass

# %%
data_ndarr = np.load(ROOT_DIR / source_file_path, allow_pickle=True)
print("data_ndarr type :", type(data_ndarr))

datadict = data_ndarr.item()
print("datadict type :", type(datadict))
# Out:
# data_ndarr type : <class 'numpy.ndarray'>
# datadict type : <class 'dict'>

# %%
p_ids = datadict.keys()

print("patients: n =", len(p_ids), end='\n\n')

for p_id in p_ids:
    df = datadict[p_id]
    # drop column from input data file
    #df.drop(['id','date','am_pef_org','BMI','sex'], axis=1, inplace=True) #ALL DROPS SHOULD OCCUR HERE
    df.drop(['id','date','am_pef_org','BMI','sex', 'age'], axis=1, inplace=True) #,'id','date','am_pef_org','BMI',  'sex', 'age'
    df = np.asarray(df).astype(np.float32)
    print(p_id, "shape:", df.shape)#, end="\t\t")

datadict[p_id].head(4)
# Out:
# patients: n = 26
#
# SB-001 shape: (188, 28)
# SB-003 shape: (180, 28)
# SB-008 shape: (178, 28)
# SB-011 shape: (210, 28)
# SB-012 shape: (194, 28)
# SB-022 shape: (204, 28)
# SB-023 shape: (194, 28)
# SB-025 shape: (117, 28)
# SB-028 shape: (92, 28)
# SB-033 shape: (53, 28)
# SB-037 shape: (210, 28)
# SB-043 shape: (191, 28)
# SB-056 shape: (191, 28)
# SB-059 shape: (203, 28)
# SB-060 shape: (88, 28)
# SB-070 shape: (202, 28)
# SB-071 shape: (124, 28)
# SB-073 shape: (161, 28)
# SB-078 shape: (153, 28)
# SB-079 shape: (142, 28)
# SB-080 shape: (181, 28)
# SB-081 shape: (34, 28)
# SB-082 shape: (137, 28)
# SB-083 shape: (206, 28)
# SB-089 shape: (49, 28)
# SB-112 shape: (180, 28)
#    income  road_dist  cooking  y_am_pef  tempin  humidin  pm25in  co2in  \
# 1   0.857        0.0    0.167     0.558   0.216    0.513   0.358  0.678
# 2   0.857        0.0    0.167     0.006   0.299    0.521   0.411  0.700
# 3   0.857        0.0    0.167     0.078   0.420    0.713   0.372  0.918
# ...

# %% [markdown]
# #### dropped columns
#
# `date` was dropped above, because it would throw `ValueError: could not convert string to float: '2017-11-01'`
# `id` and `am_pef_org` were dropped because neither are explanatory variables.
#
# SEVERITY_GROUP = 'All-DL3-005-20-1f'


### severity group A
#target_grp = ["SB-028", "SB-011", "SB-112", "SB-001", "SB-012", "SB-073", "SB-078", "SB-080", "SB-083"]
#SEVERITY_GROUP = 'A9'

#target_grp = ["SB-043", "SB-037", "SB-022", "SB-025", "SB-060", "SB-023", "SB-071"]
#SEVERITY_GROUP = 'B7'

#target_grp = ["SB-033", "SB-079", "SB-056", "SB-059", "SB-003", "SB-089", "SB-082", "SB-008", "SB-070"]
#SEVERITY_GROUP = 'C9'

# severity better one

#target_grp = ["SB-028", "SB-011", "SB-112", "SB-001", "SB-073", "SB-043", "SB-071", "SB-012", "SB-078"]
#SEVERITY_GROUP = 'AA9'

#target_grp = ["SB-079", "SB-080", "SB-083", "SB-037", "SB-022", "SB-059", "SB-003", "SB-089", "SB-025"]
#SEVERITY_GROUP = 'BB8-1'

#target_grp = ["SB-060", "SB-023", "SB-033", "SB-056", "SB-082", "SB-008", "SB-070"]
#SEVERITY_GROUP = 'CC7'

# road

#target_grp = ["SB-112", "SB-060", "SB-011", "SB-037", "SB-056", "SB-008", "SB-025", "SB-023", "SB-001", "SB-033"]
#SEVERITY_GROUP = 'D10'

#target_grp = ["SB-112", "SB-060", "SB-011", "SB-037", "SB-056", "SB-008", "SB-025", "SB-023", "SB-001", "SB-033", "SB-078"]
#SEVERITY_GROUP = 'D11'

#target_grp = ["SB-078", "SB-080", "SB-073", "SB-079", "SB-028", "SB-012", "SB-083"]
#SEVERITY_GROUP = 'E7'

#target_grp = ["SB-043", "SB-022", "SB-071", "SB-003", "SB-059", "SB-070", "SB-082", "SB-089"]
#SEVERITY_GROUP = 'F8'


# combination better

#target_grp = ["SB-112", "SB-011", "SB-001", "SB-043", "SB-012", "SB-028", "SB-078", "SB-073"]
#SEVERITY_GROUP = 'I8-DL3-005-20'

#target_grp = ["SB-071", "SB-037", "SB-025", "SB-080", "SB-003", "SB-056", "SB-083", "SB-059"]
#SEVERITY_GROUP = 'G8-DL3-005-20'


#target_grp = ["SB-089", "SB-023", "SB-022", "SB-008", "SB-079", "SB-060", "SB-033", "SB-070", "SB-082"]
#SEVERITY_GROUP = 'H9-DL3-005-20'


# cooking
#target_grp = ["SB-028", "SB-043", "SB-112", "SB-025", "SB-080", "SB-012", "SB-003"]
#SEVERITY_GROUP = "S7-DL2-005"


#target_grp = ["SB-011", "SB-037", "SB-056", "SB-070", "SB-023", "SB-083", "SB-059", "SB-082"]
#SEVERITY_GROUP = "T8-DL-005"

#target_grp = ["SB-001", "SB-089", "SB-008", "SB-033", "SB-022", "SB-071", "SB-073", "SB-060", "SB-078", "SB-079"]
#SEVERITY_GROUP = "R10-a-no"


# income
#target_grp = ["SB-001", "SB-056", "SB-078", "SB-023", "SB-003", "SB-071", "SB-073"]
#SEVERITY_GROUP = "V7"

#target_grp = ["SB-012", "SB-011", "SB-008", "SB-060", "SB-043", "SB-080", "SB-037", "SB-083", "SB-033", "SB-022"]
#SEVERITY_GROUP = "W10"

#target_grp = ["SB-112", "SB-025", "SB-089", "SB-059", "SB-070", "SB-082", "SB-079", "SB-028"]
#SEVERITY_GROUP = "Z8"

# %%
EVALUATION_METRICS = ["Weighted Accuracy", "Sensitivity/Recall", "Specificity", "Precision_class0", "Precision_class1", "Precision_avg", "F1_class0", "F1_class1", "F1_avg", "auc_roc_score", "False_Discovery_Rate", "False_Negative_Rate", "False_Omission_Rate", "False_Positive_Rate", "Jaccard"]

# %%
# from datetime import datetime
# path_date = datetime.now().strftime("%B_%d_%Y")

# RESULT_DIR = Path(f"{execution_path}/Output_Results/TL/")
RESULT_DIR = Path(f"{execution_path}/Output_Results/{Architecture_GROUP}/")

display(RESULT_DIR)
# Out:
# WindowsPath('../../../Output_Results/TL3_2f_28_32f_20f_20_1')

# %% [markdown]
# # TL_Base_Model

# %%
from tqdm import tqdm
import os.path

def TL_Base_Model(POPULATION_EPOCH_SIZE,PATIENT_EPOCH_SIZE, p_ids):
    df_evaluation_results = pd.DataFrame(columns=EVALUATION_METRICS)

    for target in tqdm(p_ids):   #for target in ["SB-003"]:
        if target not in target_grp:
            continue
        runtime()
        print("~~~~~~~~~~~", POPULATION_EPOCH_SIZE, "~~~~~~~~~~~~~~~~~~~", PATIENT_EPOCH_SIZE, "~~~~~~~~~~~~~~~~~~~", target, "~~~~~~~~~~~~~~~~~~~")

        patient_dir = RESULT_DIR / "diagrams" / target

        # create directory for this patient
        if not (patient_dir.exists() and patient_dir.is_dir()):
            os.makedirs(patient_dir)

        # setup for pre-training
        #pre_trained_model_file = Path('./model_states/') / (VERSION_TAG+'_pre_trained_model_{}.pkl'.format(target))
        #state = dict()
        #train_result = []

        # Mark: EXPLICITLY set binary outcome variable for supervised learning
        CLASS_VAR = 'class'
        # load population data
        X_train, X_test, Y_train, Y_test = split_data(target=target, data=datadict, test_frac = 0.05,
                                                    class_var=CLASS_VAR, #explanatory_var
                                                    transfer=True, balance=True)

        # pre-train model with population data
        net = network_tl(X_train, Y_train, n_hidden=32, learning_rate=0.001, device='cpu')
        net.make_pop()

        net.train(n_iters=POPULATION_EPOCH_SIZE)

        VERSION_TAG = f'TLSI_{Architecture_GROUP}_{POPULATION_EPOCH_SIZE}_{PATIENT_EPOCH_SIZE}'
        #save model
        modelname = f"{target}-{VERSION_TAG}.hdf5"
        model_path=patient_dir / modelname
        net.nn_pop.save(model_path) #nn_pop

        #save training curve
        training_curve_file = patient_dir / f'{VERSION_TAG}_training_curve_{target}'
        net.save_training_curve(training_curve_file)

        # print("target",target)
        # print("datadict",datadict)
        # print("CLASS_VAR",CLASS_VAR)

        # load target patient data
        dataset_list = split_data(target=target, data=datadict,
                                class_var=CLASS_VAR, #explanatory_var
                                balance=True)

        # print("dataset_list",dataset_list)

        # setup for k-fold cross-validation
        kfold_evaluation_results_list = []
        kfold_confusion_matrix_list = []

        for i in range(3):
            # load the target data in the current round
            X_train, X_test, Y_train, Y_test = dataset_list[i]

            # Make and train a copy of the population model with
            # all but the last layer frozen.
            net.make_ind()
            net.retrain(X_train, Y_train, n_iters=PATIENT_EPOCH_SIZE)
            print("done RE-training", i, "of 3", end=". ")

            # test
            VERSION_TAG = f'TLSI_{Architecture_GROUP}_{POPULATION_EPOCH_SIZE}_{PATIENT_EPOCH_SIZE}_{i}'
            #save model
            modelname = f"{target}-{VERSION_TAG}.hdf5"
            model_path=patient_dir / modelname
            net.nn_ind.save(model_path) #nn_pop

            #save retraining curve
            training_curve_file = patient_dir / f'{VERSION_TAG}_retraining_curve_{target}'
            net.save_training_curve(training_curve_file)

            # print("Calling net.test Now")
            # print("X_test",X_test)
            # print("Y_test",Y_test)
            results, c_matrix = net.test(X_test, Y_test)
            # print("results",results)
            kfold_evaluation_results_list += [results]
            kfold_confusion_matrix_list += [c_matrix]

            print("done testing", i, "of 3.")

        VERSION_TAG = f'TLSI_{Architecture_GROUP}_{POPULATION_EPOCH_SIZE}_{PATIENT_EPOCH_SIZE}'

        # save average of evaluation results
        confusion_matrixes_file = (f"{str(patient_dir)}/{VERSION_TAG}_confusion_matrix_{target}")

        avg_results = pd.DataFrame(kfold_evaluation_results_list, columns=EVALUATION_METRICS).mean().values

        avg_results = avg_results.reshape(1, 15)

        df = pd.DataFrame(avg_results, columns=EVALUATION_METRICS)
        df.index = [f"{target}_{POPULATION_EPOCH_SIZE}_{PATIENT_EPOCH_SIZE}"]
        df_evaluation_results = pd.concat([df_evaluation_results,df], axis = 0)

        net.save_confusion_matrix(kfold_confusion_matrix_list, confusion_matrixes_file)

    # output_path = os.path.join(RESULT_DIR, f'TLSI_{Architecture_GROUP}_evaluation_metrics_{sorted(set(p_ids).difference(target_grp))[0]}.csv')
    output_path = os.path.join(RESULT_DIR, f'TLSI_{Architecture_GROUP}_evaluation_metrics.csv')

    if os.path.isfile(output_path):
        df_evaluation_results.to_csv(output_path,
                                        mode='a',
                                        header=False
                                    )
    else:
                df_evaluation_results.to_csv(output_path,
                                        mode='a'
                                    )

    print("evaluation results saved for", VERSION_TAG)

# %%
POPULATION_EPOCH_SIZE = [*range(500, 1600, 500)]
PATIENT_EPOCH_SIZE = [*range(500, 1600, 500)]

# POPULATION_EPOCH_SIZE = [*range(1, 6, 2)]
# PATIENT_EPOCH_SIZE = [*range(1, 6, 2)]

print("POPULATION_EPOCH_SIZE:",POPULATION_EPOCH_SIZE, "Len:", len(POPULATION_EPOCH_SIZE))
print("PATIENT_EPOCH_SIZE:",PATIENT_EPOCH_SIZE, "Len:", len(PATIENT_EPOCH_SIZE))
print("target_grp:",target_grp, "Len:", len(target_grp))
print("Total records in each file:",len(POPULATION_EPOCH_SIZE) * len(PATIENT_EPOCH_SIZE) * len(target_grp))
# Out:
# POPULATION_EPOCH_SIZE: [500, 1000, 1500] Len: 3
# PATIENT_EPOCH_SIZE: [500, 1000, 1500] Len: 3
# target_grp: ['SB-001', 'SB-003', 'SB-008', 'SB-011', 'SB-012', 'SB-022', 'SB-023', 'SB-025', 'SB-028', 'SB-033', 'SB-037', 'SB-043', 'SB-056', 'SB-059', 'SB-060', 'SB-070', 'SB-071', 'SB-073', 'SB-078', 'SB-079', 'SB-080', 'SB-082', 'SB-083', 'SB-089', 'SB-112'] Len: 25
# Total records in each file: 225

# %% [markdown]
# # Execution

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[0],PATIENT_EPOCH_SIZE[0], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 16 o' clock and 47 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 4 14]
#  [ 8 37]]
# cm.ravel() [ 4 14  8 37]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 2  6]
#  [26 29]]
# cm.ravel() [ 2  6 26 29]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 2ms/step
# cm [[ 2  9]
#  [14 37]]
# cm.ravel() [ 2  9 14 37]
# done testing 2 of 3.
#   4%|▍         | 1/26 [00:45<19:02, 45.72s/it]
# Runtime: 16 o' clock and 48 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 5  8]
#  [15 32]]
# cm.ravel() [ 5  8 15 32]
# done testing 0 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[0],PATIENT_EPOCH_SIZE[1], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 17 o' clock and 6 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 0s/step
# cm [[ 3 12]
#  [ 9 39]]
# cm.ravel() [ 3 12  9 39]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 2ms/step
# cm [[ 2 10]
#  [15 36]]
# cm.ravel() [ 2 10 15 36]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 0s/step
# cm [[ 4  6]
#  [14 38]]
# cm.ravel() [ 4  6 14 38]
# done testing 2 of 3.
#   4%|▍         | 1/26 [00:56<23:22, 56.10s/it]
# Runtime: 17 o' clock and 7 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 4 13]
#  [17 26]]
# cm.ravel() [ 4 13 17 26]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 0s/step
# cm [[ 2 12]
#  [14 32]]
# cm.ravel() [ 2 12 14 32]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[0],PATIENT_EPOCH_SIZE[2], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 17 o' clock and 30 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 0s/step
# cm [[ 5  8]
#  [15 35]]
# cm.ravel() [ 5  8 15 35]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 2ms/step
# cm [[ 4  7]
#  [17 35]]
# cm.ravel() [ 4  7 17 35]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 4  9]
#  [15 34]]
# cm.ravel() [ 4  9 15 34]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:01<25:28, 61.12s/it]
# Runtime: 17 o' clock and 31 minutes
# ~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 0s/step
# cm [[ 5 10]
#  [18 27]]
# cm.ravel() [ 5 10 18 27]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 5  8]
#  [16 31]]
# cm.ravel() [ 5  8 16 31]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[1],PATIENT_EPOCH_SIZE[0], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 17 o' clock and 56 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 5 11]
#  [12 35]]
# cm.ravel() [ 5 11 12 35]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 9  4]
#  [13 37]]
# cm.ravel() [ 9  4 13 37]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 1  7]
#  [24 30]]
# cm.ravel() [ 1  7 24 30]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:44<43:35, 104.62s/it]
# Runtime: 17 o' clock and 58 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 4 11]
#  [ 9 36]]
# cm.ravel() [ 4 11  9 36]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 4  8]
#  [23 25]]
# cm.ravel() [ 4  8 23 25]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[1],PATIENT_EPOCH_SIZE[1], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 18 o' clock and 41 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 4ms/step
# cm [[ 3  5]
#  [24 31]]
# cm.ravel() [ 3  5 24 31]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 4  7]
#  [17 35]]
# cm.ravel() [ 4  7 17 35]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 5ms/step
# cm [[ 6 12]
#  [10 34]]
# cm.ravel() [ 6 12 10 34]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:55<47:56, 115.05s/it]
# Runtime: 18 o' clock and 43 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 7  8]
#  [15 30]]
# cm.ravel() [ 7  8 15 30]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 6ms/step
# cm [[ 3 10]
#  [16 31]]
# cm.ravel() [ 3 10 16 31]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[1],PATIENT_EPOCH_SIZE[2], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 19 o' clock and 33 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 0s/step
# cm [[ 2 12]
#  [10 39]]
# cm.ravel() [ 2 12 10 39]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 0s/step
# cm [[ 3  9]
#  [14 37]]
# cm.ravel() [ 3  9 14 37]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 0s/step
# cm [[ 3  8]
#  [12 39]]
# cm.ravel() [ 3  8 12 39]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:33<38:53, 93.35s/it]
# Runtime: 19 o' clock and 34 minutes
# ~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 15ms/step
# cm [[ 7 14]
#  [11 28]]
# cm.ravel() [ 7 14 11 28]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 1ms/step
# cm [[ 4  9]
#  [11 36]]
# cm.ravel() [ 4  9 11 36]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[2],PATIENT_EPOCH_SIZE[0], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 20 o' clock and 12 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 2ms/step
# cm [[ 6  7]
#  [19 31]]
# cm.ravel() [ 6  7 19 31]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 4ms/step
# cm [[ 5 11]
#  [16 31]]
# cm.ravel() [ 5 11 16 31]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 3  5]
#  [18 36]]
# cm.ravel() [ 3  5 18 36]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:51<46:15, 111.01s/it]
# Runtime: 20 o' clock and 14 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 5  6]
#  [21 28]]
# cm.ravel() [ 5  6 21 28]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 4ms/step
# cm [[ 9  7]
#  [16 28]]
# cm.ravel() [ 9  7 16 28]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[2],PATIENT_EPOCH_SIZE[1], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 21 o' clock and 2 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 5  3]
#  [18 37]]
# cm.ravel() [ 5  3 18 37]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 4ms/step
# cm [[ 3 11]
#  [13 36]]
# cm.ravel() [ 3 11 13 36]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 6  9]
#  [15 32]]
# cm.ravel() [ 6  9 15 32]
# done testing 2 of 3.
#   4%|▍         | 1/26 [01:59<49:52, 119.69s/it]
# Runtime: 21 o' clock and 4 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 1000 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 2ms/step
# cm [[ 8  8]
#  [13 31]]
# cm.ravel() [ 8  8 13 31]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 6  5]
#  [18 31]]
# cm.ravel() [ 6  5 18 31]
# done testing 1 of 3.
# ...

# %%
TL_Base_Model(POPULATION_EPOCH_SIZE[2],PATIENT_EPOCH_SIZE[2], p_ids)
# Out:
#   0%|          | 0/26 [00:00<?, ?it/s]
# Runtime: 10 o' clock and 21 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-001 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 4  5]
#  [19 35]]
# cm.ravel() [ 4  5 19 35]
# done testing 0 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 2 16]
#  [10 35]]
# cm.ravel() [ 2 16 10 35]
# done testing 1 of 3.
# 2/2 [==============================] - 0s 3ms/step
# cm [[ 7  3]
#  [17 35]]
# cm.ravel() [ 7  3 17 35]
# done testing 2 of 3.
#   4%|▍         | 1/26 [02:03<51:35, 123.83s/it]
# Runtime: 10 o' clock and 23 minutes
# ~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ 1500 ~~~~~~~~~~~~~~~~~~~ SB-003 ~~~~~~~~~~~~~~~~~~~
# 2/2 [==============================] - 0s 0s/step
# cm [[ 3 10]
#  [14 33]]
# cm.ravel() [ 3 10 14 33]
# done testing 0 of 3.
# ...

# %% [markdown]
# # End
